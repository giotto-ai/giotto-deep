# %%
1+1
# Out:
# 2

# %%
class Test():
    def __init__(self):
        print("class construed")

t = Test()
# Out:
# class construed

# %%
breakpoint()
class Test():
    def __init__(self):
        print("class constructed")

t = Test()
# Out:
# class constructed

# %%
1+1
# Out:
# 2
