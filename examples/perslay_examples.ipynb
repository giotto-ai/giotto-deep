# %%
import numpy as np  # type: ignore
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import gc
import multiprocessing
import os
from einops import rearrange  # type: ignore
from gtda.homology import WeakAlphaPersistence  # type: ignore
from gtda.plotting import plot_diagram  # type: ignore
from gdeep.create_data import generate_orbit
from gdeep.topology_layers import SmallSetTransformer, ISAB, PMA, SAB

# %%
try:
    assert os.path.isdir('./data/ORBIT5K')
except AssertionError:
    if not os.path.isdir('./data'):
        os.mkdir('./data')
    os.mkdir('./data/ORBIT5K')

# If `use_precomputed_dgms` is `False` the ORBIT5K dataset will
# be recomputed, otherwise the ORBIT5K dataset in the folder
# `data/ORBIT5K` will be used
use_precomputed_dgms = False

dgms_filename = os.path.join('data', 'ORBIT5K',
                             'alpha_persistence_diagrams.npy')
dgms_filename_validation = os.path.join('data', 'ORBIT5K',
                             'alpha_persistence_diagrams_validation.npy')

if use_precomputed_dgms:
    try:
        assert(os.path.isfile(dgms_filename))
    except AssertionError:
        print('File data/ORBIT5K/alpha_persistence_diagrams.npy',
              ' does not exist.')
    try:
        assert(os.path.isfile(dgms_filename_validation))
    except AssertionError:
        print('File data/ORBIT5K/alpha_persistence_diagrams.npy',
              ' does not exist.')

# %%
parameters = (2.5, 3.5, 4.0, 4.1, 4.3)  # different classes of orbits
homology_dimensions = (0, 1)

config = {
    'parameters': parameters,
    'num_classes': len(parameters),
    'num_orbits': 1_000,
    'num_pts_per_orbit': 1_000,
    'homology_dimensions': homology_dimensions,
    'num_homology_dimensions': len(homology_dimensions),
    'validation_percentage': 100,
}

if not use_precomputed_dgms:
    for dataset_type in ['train', 'validation']:
        # Generate dataset consisting of 5 different orbit types with
        # 1000 sampled data points each.
        # This is the dataset ORBIT5K used in the PersLay paper
        if dataset_type == 'train':
            num_orbits = config['num_orbits']
        else:
            num_orbits = int(config['num_orbits'] 
                            * config['validation_percentage'] / 100)
        x = np.zeros((
                        config['num_classes'],  # type: ignore
                        num_orbits,
                        config['num_pts_per_orbit'],
                        2
                    ))

        # generate dataset
        for cidx, p in enumerate(config['parameters']):  # type: ignore
            x[cidx, :, 0, :] = np.random.rand(num_orbits, 2)

            for i in range(1, config['num_pts_per_orbit']):  # type: ignore
                x_cur = x[cidx, :, i - 1, 0]
                y_cur = x[cidx, :, i - 1, 1]

                x[cidx, :, i, 0] = (x_cur + p * y_cur * (1. - y_cur)) % 1
                x_next = x[cidx, :, i, 0]
                x[cidx, :, i, 1] = (y_cur + p * x_next * (1. - x_next)) % 1


        """
        # old non-parallel version
        for cidx, p in enumerate(config['parameters']):  # type: ignore
            for i in range(config['num_orbits']):  # type: ignore
                x[cidx][i] = generate_orbit(
                    num_pts_per_orbit=config['num_pts_per_orbit'],  # type: ignore
                    parameter=p
                    )
        """

        assert(not np.allclose(x[0,0], x[0,1]))

        # compute weak alpha persistence
        wap = WeakAlphaPersistence(
                            homology_dimensions=config['homology_dimensions'],
                            n_jobs=multiprocessing.cpu_count()
                            )
        # c: class, o: orbit, p: point, d: dimension
        x_stack = rearrange(x, 'c o p d -> (c o) p d')  # stack classes
        diagrams = wap.fit_transform(x_stack)
        # shape: (num_classes * n_samples, n_features, 3)

        diagrams = rearrange(
                                diagrams,
                                '(c o) p d -> c o p d',
                                c=config['num_classes']  # type: ignore
                            )

        # plot sample persistence diagrams
        if(False):
            plot_diagram(diagrams[1, 2])
            plot_diagram(diagrams[2, 2])

        # save dataset
        if dataset_type == 'train':
            with open(dgms_filename_, 'wb') as f:
                np.save(f, diagrams)
        else:
            with open(dgms_filename_validation, 'wb') as f:
                np.save(f, diagrams)

# %%
# load dataset
with open(dgms_filename, 'rb') as f:
    x = np.load(f)

# c: class, o: orbit, p: point in persistence diagram,
# d: coordinates + homology dimension
x = rearrange(
                x,
                'c o p d -> (c o) p d',
                c=config['num_classes']  # type: ignore
            )
# convert homology dimension to one-hot encoding
x = np.concatenate(
    (
        x[:, :, :2],
        (np.eye(config['num_homology_dimensions'])
         [x[:, :, -1].astype(np.int32)]),
    ),
    axis=-1)
# convert from [orbit, sequence_length, feature] to
# [orbit, feature, sequence_length] to fit to the
# input_shape of `SmallSetTransformer`
#x = rearrange(x, 'o s f -> o f s')

# generate labels
y_list = []
for i in range(config['num_classes']):  # type: ignore
    y_list += [i] * config['num_orbits']  # type: ignore

y = np.array(y_list)


# load dataset to PyTorch dataloader

x_tensor = torch.Tensor(x)
y_tensor = torch.Tensor(y)

dataset = TensorDataset(x_tensor, y_tensor)
dataloader = DataLoader(dataset,
                        shuffle=True,
                        batch_size=64,
                        num_workers=6,
                        pin_memory=True
                        )

# %%
# load dataset
with open(dgms_filename_validation, 'rb') as f:
    x = np.load(f)

# c: class, o: orbit, p: point in persistence diagram,
# d: coordinates + homology dimension
x = rearrange(
                x,
                'c o p d -> (c o) p d',
                c=config['num_classes']  # type: ignore
            )
# convert homology dimension to one-hot encoding
x = np.concatenate(
    (
        x[:, :, :2],
        (np.eye(config['num_homology_dimensions'])
         [x[:, :, -1].astype(np.int32)]),
    ),
    axis=-1)
# convert from [orbit, sequence_length, feature] to
# [orbit, feature, sequence_length] to fit to the
# input_shape of `SmallSetTransformer`
#x = rearrange(x, 'o s f -> o f s')

# generate labels
y_list = []
for i in range(config['num_classes']):  # type: ignore
    y_list += [i] * config['num_orbits']  # type: ignore

y = np.array(y_list)


# load dataset to PyTorch dataloader

x_tensor = torch.Tensor(x)
y_tensor = torch.Tensor(y)

dataset = TensorDataset(x_tensor, y_tensor)
dataloader_validation = DataLoader(dataset,
                        shuffle=True,
                        batch_size=64,
                        num_workers=6,
                        pin_memory=True
                        )

# %%
# initialize SmallSetTransformer model
"""model = SmallSetTransformer(
                            dim_input=4,
                            dim_out=64,
                            num_heads=4,
                            out_features=config['num_classes']  # type: ignore
                            )
"""

class SetTransformer(nn.Module):
    def __init__(
        self,
        dim_input=3,
        num_outputs=1,
        dim_output=40,
        num_inds=32,
        dim_hidden=128,
        num_heads=4,
        ln=False,
    ):
        super(SetTransformer, self).__init__()
        self.enc = nn.Sequential(
            ISAB(dim_input, dim_hidden, num_heads, num_inds, ln=ln),
            ISAB(dim_hidden, dim_hidden, num_heads, num_inds, ln=ln),
        )
        self.dec = nn.Sequential(
            nn.Dropout(),
            PMA(dim_hidden, num_heads, num_outputs, ln=ln),
            nn.Dropout(),
            nn.Linear(dim_hidden, dim_output),
        )

    def forward(self, X):
        return self.dec(self.enc(X)).squeeze()

model = SetTransformer(dim_input=4, dim_output=5)

#print('model has', model.num_params(), 'trainable parameters.')

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")

# %%
def train(model, num_epochs: int = 10, lr: float = 1e-3,
          verbose: bool = False, compute_accuracy: bool = False):
    if use_cuda:
        model = nn.DataParallel(model)
        model = model.cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    losses = []

    # training loop
    for epoch in range(num_epochs):
        model.train()
        loss_per_epoch = 0
        for x_batch, y_batch in dataloader:
            # transfer to GPU
            if use_cuda:
                x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
            loss = criterion(model(x_batch), y_batch.long())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_per_epoch += loss.item()
            #print(loss.item())
        losses.append(loss_per_epoch)
        if verbose:
            print("epoch:", epoch, "loss:", loss_per_epoch)

        if compute_accuracy:
            # test accuracy
            correct = 0
            total = 0

            with torch.no_grad():
                for x_batch, y_batch in dataloader:
                    if use_cuda:
                            x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
                    outputs = model(x_batch).squeeze(1)
                    _, predictions = torch.max(outputs, 1)
                    total += y_batch.size(0)
                    correct += (predictions == y_batch).sum().item()

            print('Test accuracy of the network on the 5000 test diagrams: %8.2f %%' % (
                100 * correct / total))
            # validation accuracy
            correct = 0
            total = 0

            with torch.no_grad():
                for x_batch, y_batch in dataloader_validation:
                    if use_cuda:
                            x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
                    outputs = model(x_batch).squeeze(1)
                    _, predictions = torch.max(outputs, 1)
                    total += y_batch.size(0)
                    correct += (predictions == y_batch).sum().item()

            print('Validation accuracy of the network on the 5000 test diagrams: %8.2f %%' % (
                100 * correct / total))
    return losses

# %%
train(model, num_epochs=500, verbose=True, compute_accuracy=True)
# Out:
# epoch: 0 loss: 20.747889026999474
# Test accuracy of the network on the 5000 test diagrams:    90.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 1 loss: 20.65145505219698
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    88.82 %
# epoch: 2 loss: 20.403223231434822
# Test accuracy of the network on the 5000 test diagrams:    88.38 %
# Validation accuracy of the network on the 5000 test diagrams:    87.36 %
# epoch: 3 loss: 22.15877155959606
# Test accuracy of the network on the 5000 test diagrams:    89.22 %
# Validation accuracy of the network on the 5000 test diagrams:    88.60 %
# epoch: 4 loss: 19.879891455173492
# Test accuracy of the network on the 5000 test diagrams:    89.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 5 loss: 19.693836897611618
# Test accuracy of the network on the 5000 test diagrams:    89.06 %
# Validation accuracy of the network on the 5000 test diagrams:    87.98 %
# epoch: 6 loss: 19.675016447901726
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 7 loss: 19.363330580294132
# Test accuracy of the network on the 5000 test diagrams:    89.44 %
# Validation accuracy of the network on the 5000 test diagrams:    88.38 %
# epoch: 8 loss: 19.44016182422638
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 9 loss: 18.9577427059412
# Test accuracy of the network on the 5000 test diagrams:    89.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 10 loss: 19.897639617323875
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 11 loss: 20.536432534456253
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 12 loss: 19.505483224987984
# Test accuracy of the network on the 5000 test diagrams:    89.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 13 loss: 19.21921593695879
# Test accuracy of the network on the 5000 test diagrams:    90.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 14 loss: 20.123308464884758
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 15 loss: 19.498684279620647
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 16 loss: 19.730875335633755
# Test accuracy of the network on the 5000 test diagrams:    89.74 %
# Validation accuracy of the network on the 5000 test diagrams:    88.98 %
# epoch: 17 loss: 19.30934865772724
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 18 loss: 18.915795024484396
# Test accuracy of the network on the 5000 test diagrams:    89.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 19 loss: 20.589476868510246
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 20 loss: 20.251872450113297
# Test accuracy of the network on the 5000 test diagrams:    88.28 %
# Validation accuracy of the network on the 5000 test diagrams:    88.48 %
# epoch: 21 loss: 19.54478994011879
# Test accuracy of the network on the 5000 test diagrams:    89.88 %
# Validation accuracy of the network on the 5000 test diagrams:    88.32 %
# epoch: 22 loss: 21.2074057161808
# Test accuracy of the network on the 5000 test diagrams:    89.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.12 %
# epoch: 23 loss: 19.810751482844353
# Test accuracy of the network on the 5000 test diagrams:    90.10 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 24 loss: 19.04927945137024
# Test accuracy of the network on the 5000 test diagrams:    90.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 25 loss: 19.38615544140339
# Test accuracy of the network on the 5000 test diagrams:    90.30 %
# Validation accuracy of the network on the 5000 test diagrams:    90.08 %
# epoch: 26 loss: 19.275047704577446
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 27 loss: 19.48431959748268
# Test accuracy of the network on the 5000 test diagrams:    89.84 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 28 loss: 19.619800619781017
# Test accuracy of the network on the 5000 test diagrams:    89.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 29 loss: 19.519689172506332
# Test accuracy of the network on the 5000 test diagrams:    90.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 30 loss: 19.426263887435198
# Test accuracy of the network on the 5000 test diagrams:    89.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 31 loss: 20.351188600063324
# Test accuracy of the network on the 5000 test diagrams:    89.98 %
# Validation accuracy of the network on the 5000 test diagrams:    89.04 %
# epoch: 32 loss: 19.604546420276165
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 33 loss: 20.618958920240402
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 34 loss: 22.48147886991501
# Test accuracy of the network on the 5000 test diagrams:    88.38 %
# Validation accuracy of the network on the 5000 test diagrams:    87.98 %
# epoch: 35 loss: 25.309450939297676
# Test accuracy of the network on the 5000 test diagrams:    90.10 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 36 loss: 20.21900037676096
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    88.00 %
# epoch: 37 loss: 19.108687222003937
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 38 loss: 19.23652637563646
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 39 loss: 19.176945492625237
# Test accuracy of the network on the 5000 test diagrams:    90.98 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 40 loss: 19.64499705284834
# Test accuracy of the network on the 5000 test diagrams:    90.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 41 loss: 18.67485513538122
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 42 loss: 18.681979089975357
# Test accuracy of the network on the 5000 test diagrams:    87.78 %
# Validation accuracy of the network on the 5000 test diagrams:    87.66 %
# epoch: 43 loss: 19.130590957589447
# Test accuracy of the network on the 5000 test diagrams:    90.10 %
# Validation accuracy of the network on the 5000 test diagrams:    88.52 %
# epoch: 44 loss: 19.176518999040127
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 45 loss: 19.152336910367012
# Test accuracy of the network on the 5000 test diagrams:    90.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 46 loss: 19.355161927640438
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 47 loss: 18.850413415580988
# Test accuracy of the network on the 5000 test diagrams:    89.82 %
# Validation accuracy of the network on the 5000 test diagrams:    88.48 %
# epoch: 48 loss: 18.658433236181736
# Test accuracy of the network on the 5000 test diagrams:    90.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 49 loss: 19.136043176054955
# Test accuracy of the network on the 5000 test diagrams:    87.42 %
# Validation accuracy of the network on the 5000 test diagrams:    84.76 %
# epoch: 50 loss: 19.72250735014677
# Test accuracy of the network on the 5000 test diagrams:    90.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 51 loss: 19.370171554386616
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 52 loss: 19.215360939502716
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 53 loss: 20.086062289774418
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 54 loss: 18.772899366915226
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    88.88 %
# epoch: 55 loss: 19.01672700792551
# Test accuracy of the network on the 5000 test diagrams:    90.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 56 loss: 19.984723672270775
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 57 loss: 19.432552695274353
# Test accuracy of the network on the 5000 test diagrams:    90.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.06 %
# epoch: 58 loss: 19.809822127223015
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 59 loss: 19.935061760246754
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 60 loss: 20.449982427060604
# Test accuracy of the network on the 5000 test diagrams:    89.00 %
# Validation accuracy of the network on the 5000 test diagrams:    87.86 %
# epoch: 61 loss: 19.347118861973286
# Test accuracy of the network on the 5000 test diagrams:    89.18 %
# Validation accuracy of the network on the 5000 test diagrams:    88.14 %
# epoch: 62 loss: 19.031611278653145
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 63 loss: 20.24380374699831
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 64 loss: 19.81159383058548
# Test accuracy of the network on the 5000 test diagrams:    89.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.46 %
# epoch: 65 loss: 19.64027851819992
# Test accuracy of the network on the 5000 test diagrams:    90.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 66 loss: 19.28117172420025
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.96 %
# epoch: 67 loss: 19.473004579544067
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 68 loss: 19.355512894690037
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 69 loss: 19.629364907741547
# Test accuracy of the network on the 5000 test diagrams:    89.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 70 loss: 22.53117224574089
# Test accuracy of the network on the 5000 test diagrams:    89.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 71 loss: 19.71199019998312
# Test accuracy of the network on the 5000 test diagrams:    89.92 %
# Validation accuracy of the network on the 5000 test diagrams:    88.94 %
# epoch: 72 loss: 20.10910116136074
# Test accuracy of the network on the 5000 test diagrams:    90.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 73 loss: 19.95346738025546
# Test accuracy of the network on the 5000 test diagrams:    90.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 74 loss: 19.188880562782288
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 75 loss: 23.70314695313573
# Test accuracy of the network on the 5000 test diagrams:    90.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 76 loss: 19.379848286509514
# Test accuracy of the network on the 5000 test diagrams:    89.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 77 loss: 19.02339281141758
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 78 loss: 18.981436416506767
# Test accuracy of the network on the 5000 test diagrams:    90.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 79 loss: 19.77435465157032
# Test accuracy of the network on the 5000 test diagrams:    90.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.10 %
# epoch: 80 loss: 19.450620852410793
# Test accuracy of the network on the 5000 test diagrams:    90.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 81 loss: 19.458521619439125
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 82 loss: 18.646914415061474
# Test accuracy of the network on the 5000 test diagrams:    90.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 83 loss: 18.047999314963818
# Test accuracy of the network on the 5000 test diagrams:    90.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 84 loss: 19.202477544546127
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 85 loss: 19.152652107179165
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    90.04 %
# epoch: 86 loss: 18.862824857234955
# Test accuracy of the network on the 5000 test diagrams:    90.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.12 %
# epoch: 87 loss: 20.531135834753513
# Test accuracy of the network on the 5000 test diagrams:    88.92 %
# Validation accuracy of the network on the 5000 test diagrams:    87.94 %
# epoch: 88 loss: 20.01679115742445
# Test accuracy of the network on the 5000 test diagrams:    89.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 89 loss: 19.53817232325673
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 90 loss: 18.982172705233097
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 91 loss: 19.522930532693863
# Test accuracy of the network on the 5000 test diagrams:    90.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 92 loss: 19.05940624512732
# Test accuracy of the network on the 5000 test diagrams:    89.98 %
# Validation accuracy of the network on the 5000 test diagrams:    88.80 %
# epoch: 93 loss: 19.14199759066105
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    88.94 %
# epoch: 94 loss: 20.07527581602335
# Test accuracy of the network on the 5000 test diagrams:    89.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 95 loss: 19.5769202709198
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    90.32 %
# epoch: 96 loss: 18.43622412532568
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 97 loss: 18.407309643924236
# Test accuracy of the network on the 5000 test diagrams:    90.84 %
# Validation accuracy of the network on the 5000 test diagrams:    90.12 %
# epoch: 98 loss: 18.886694237589836
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 99 loss: 23.336259230971336
# Test accuracy of the network on the 5000 test diagrams:    78.72 %
# Validation accuracy of the network on the 5000 test diagrams:    77.90 %
# epoch: 100 loss: 75.15317237377167
# Test accuracy of the network on the 5000 test diagrams:    82.84 %
# Validation accuracy of the network on the 5000 test diagrams:    82.24 %
# epoch: 101 loss: 30.441627621650696
# Test accuracy of the network on the 5000 test diagrams:    85.90 %
# Validation accuracy of the network on the 5000 test diagrams:    86.70 %
# epoch: 102 loss: 22.64421896636486
# Test accuracy of the network on the 5000 test diagrams:    88.20 %
# Validation accuracy of the network on the 5000 test diagrams:    86.78 %
# epoch: 103 loss: 21.74629235267639
# Test accuracy of the network on the 5000 test diagrams:    89.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 104 loss: 20.438878536224365
# Test accuracy of the network on the 5000 test diagrams:    89.00 %
# Validation accuracy of the network on the 5000 test diagrams:    88.98 %
# epoch: 105 loss: 21.395177632570267
# Test accuracy of the network on the 5000 test diagrams:    89.62 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 106 loss: 20.52278524171561
# Test accuracy of the network on the 5000 test diagrams:    89.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 107 loss: 20.38651465624571
# Test accuracy of the network on the 5000 test diagrams:    90.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 108 loss: 19.888123102486134
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 109 loss: 19.95175191015005
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 110 loss: 20.074973806738853
# Test accuracy of the network on the 5000 test diagrams:    89.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.84 %
# epoch: 111 loss: 20.042950816452503
# Test accuracy of the network on the 5000 test diagrams:    88.06 %
# Validation accuracy of the network on the 5000 test diagrams:    88.18 %
# epoch: 112 loss: 20.32078316807747
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 113 loss: 19.858730606734753
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 114 loss: 19.65034320577979
# Test accuracy of the network on the 5000 test diagrams:    89.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 115 loss: 19.56825517117977
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 116 loss: 19.16908736526966
# Test accuracy of the network on the 5000 test diagrams:    90.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 117 loss: 19.065432101488113
# Test accuracy of the network on the 5000 test diagrams:    89.74 %
# Validation accuracy of the network on the 5000 test diagrams:    88.92 %
# epoch: 118 loss: 20.17322351783514
# Test accuracy of the network on the 5000 test diagrams:    89.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.04 %
# epoch: 119 loss: 19.768902353942394
# Test accuracy of the network on the 5000 test diagrams:    89.76 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 120 loss: 19.41501072049141
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 121 loss: 19.52943103760481
# Test accuracy of the network on the 5000 test diagrams:    90.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 122 loss: 19.087099440395832
# Test accuracy of the network on the 5000 test diagrams:    90.10 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 123 loss: 18.947231575846672
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 124 loss: 18.91526820510626
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 125 loss: 22.232127279043198
# Test accuracy of the network on the 5000 test diagrams:    89.64 %
# Validation accuracy of the network on the 5000 test diagrams:    88.64 %
# epoch: 126 loss: 20.846785366535187
# Test accuracy of the network on the 5000 test diagrams:    89.78 %
# Validation accuracy of the network on the 5000 test diagrams:    88.22 %
# epoch: 127 loss: 19.55872804671526
# Test accuracy of the network on the 5000 test diagrams:    90.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 128 loss: 19.295034363865852
# Test accuracy of the network on the 5000 test diagrams:    90.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 129 loss: 20.030160948634148
# Test accuracy of the network on the 5000 test diagrams:    90.76 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 130 loss: 19.889808237552643
# Test accuracy of the network on the 5000 test diagrams:    90.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 131 loss: 19.032955832779408
# Test accuracy of the network on the 5000 test diagrams:    90.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 132 loss: 18.652519047260284
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    90.12 %
# epoch: 133 loss: 18.65481685101986
# Test accuracy of the network on the 5000 test diagrams:    89.50 %
# Validation accuracy of the network on the 5000 test diagrams:    88.18 %
# epoch: 134 loss: 19.379982627928257
# Test accuracy of the network on the 5000 test diagrams:    90.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 135 loss: 18.92787417769432
# Test accuracy of the network on the 5000 test diagrams:    90.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 136 loss: 18.980670139193535
# Test accuracy of the network on the 5000 test diagrams:    89.84 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 137 loss: 19.06461938470602
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 138 loss: 18.292036797851324
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 139 loss: 18.51029296964407
# Test accuracy of the network on the 5000 test diagrams:    91.18 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 140 loss: 18.87052471935749
# Test accuracy of the network on the 5000 test diagrams:    90.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 141 loss: 18.801198296248913
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 142 loss: 18.300055995583534
# Test accuracy of the network on the 5000 test diagrams:    88.52 %
# Validation accuracy of the network on the 5000 test diagrams:    87.72 %
# epoch: 143 loss: 19.298768222332
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 144 loss: 19.15946315228939
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    88.98 %
# epoch: 145 loss: 18.553878232836723
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 146 loss: 19.482360631227493
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 147 loss: 19.717759385704994
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.84 %
# epoch: 148 loss: 18.381419360637665
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 149 loss: 19.46101277321577
# Test accuracy of the network on the 5000 test diagrams:    90.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.94 %
# epoch: 150 loss: 18.644518613815308
# Test accuracy of the network on the 5000 test diagrams:    90.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 151 loss: 18.151390550658107
# Test accuracy of the network on the 5000 test diagrams:    91.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 152 loss: 18.61205697618425
# Test accuracy of the network on the 5000 test diagrams:    90.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 153 loss: 18.92248486727476
# Test accuracy of the network on the 5000 test diagrams:    90.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 154 loss: 18.108482838608325
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 155 loss: 18.499680453911424
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 156 loss: 19.071105778217316
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    88.64 %
# epoch: 157 loss: 19.411020025610924
# Test accuracy of the network on the 5000 test diagrams:    90.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.84 %
# epoch: 158 loss: 19.176791951060295
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 159 loss: 18.79061149759218
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 160 loss: 19.054873637855053
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 161 loss: 19.57502706348896
# Test accuracy of the network on the 5000 test diagrams:    89.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 162 loss: 19.130050502717495
# Test accuracy of the network on the 5000 test diagrams:    89.88 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 163 loss: 19.410554721951485
# Test accuracy of the network on the 5000 test diagrams:    90.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 164 loss: 20.077072247862816
# Test accuracy of the network on the 5000 test diagrams:    90.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 165 loss: 19.525215730071068
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.88 %
# epoch: 166 loss: 19.625617001671344
# Test accuracy of the network on the 5000 test diagrams:    90.18 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 167 loss: 20.214459367096424
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 168 loss: 18.992615941911936
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 169 loss: 18.73714130371809
# Test accuracy of the network on the 5000 test diagrams:    90.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 170 loss: 18.579123876988888
# Test accuracy of the network on the 5000 test diagrams:    90.28 %
# Validation accuracy of the network on the 5000 test diagrams:    90.16 %
# epoch: 171 loss: 18.25071892887354
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    88.34 %
# epoch: 172 loss: 18.298283524811268
# Test accuracy of the network on the 5000 test diagrams:    90.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 173 loss: 18.06216725707054
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    88.82 %
# epoch: 174 loss: 18.775686532258987
# Test accuracy of the network on the 5000 test diagrams:    89.86 %
# Validation accuracy of the network on the 5000 test diagrams:    88.50 %
# epoch: 175 loss: 19.327721789479256
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    88.18 %
# epoch: 176 loss: 19.52349530160427
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 177 loss: 19.022172041237354
# Test accuracy of the network on the 5000 test diagrams:    90.96 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 178 loss: 19.088169530034065
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 179 loss: 18.97410038113594
# Test accuracy of the network on the 5000 test diagrams:    89.22 %
# Validation accuracy of the network on the 5000 test diagrams:    87.96 %
# epoch: 180 loss: 19.099428728222847
# Test accuracy of the network on the 5000 test diagrams:    90.20 %
# Validation accuracy of the network on the 5000 test diagrams:    88.92 %
# epoch: 181 loss: 18.497783295810223
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 182 loss: 18.807782545685768
# Test accuracy of the network on the 5000 test diagrams:    89.40 %
# Validation accuracy of the network on the 5000 test diagrams:    88.12 %
# epoch: 183 loss: 19.527277022600174
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 184 loss: 19.33628150820732
# Test accuracy of the network on the 5000 test diagrams:    89.90 %
# Validation accuracy of the network on the 5000 test diagrams:    88.74 %
# epoch: 185 loss: 19.177831441164017
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 186 loss: 18.51257561892271
# Test accuracy of the network on the 5000 test diagrams:    90.08 %
# Validation accuracy of the network on the 5000 test diagrams:    88.26 %
# epoch: 187 loss: 18.45180903468281
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 188 loss: 18.194550059735775
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 189 loss: 19.049149490892887
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 190 loss: 19.516482021659613
# Test accuracy of the network on the 5000 test diagrams:    86.62 %
# Validation accuracy of the network on the 5000 test diagrams:    86.60 %
# epoch: 191 loss: 19.907648339867592
# Test accuracy of the network on the 5000 test diagrams:    89.92 %
# Validation accuracy of the network on the 5000 test diagrams:    88.64 %
# epoch: 192 loss: 18.591876413673162
# Test accuracy of the network on the 5000 test diagrams:    90.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 193 loss: 19.77905486524105
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 194 loss: 19.427528388798237
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 195 loss: 18.498423665761948
# Test accuracy of the network on the 5000 test diagrams:    91.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 196 loss: 18.459959499537945
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 197 loss: 20.76567144691944
# Test accuracy of the network on the 5000 test diagrams:    90.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 198 loss: 18.899810649454594
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 199 loss: 18.39121450483799
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 200 loss: 19.154430359601974
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 201 loss: 19.385520197451115
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 202 loss: 18.324989780783653
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 203 loss: 18.89291825145483
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 204 loss: 19.488332100212574
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 205 loss: 19.279757879674435
# Test accuracy of the network on the 5000 test diagrams:    90.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 206 loss: 18.383467730134726
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 207 loss: 20.20944045484066
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    88.90 %
# epoch: 208 loss: 18.437771789729595
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    90.08 %
# epoch: 209 loss: 18.691356725990772
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 210 loss: 18.809736743569374
# Test accuracy of the network on the 5000 test diagrams:    90.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 211 loss: 19.589019164443016
# Test accuracy of the network on the 5000 test diagrams:    89.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.68 %
# epoch: 212 loss: 18.66381562501192
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 213 loss: 22.11755057424307
# Test accuracy of the network on the 5000 test diagrams:    89.82 %
# Validation accuracy of the network on the 5000 test diagrams:    88.88 %
# epoch: 214 loss: 20.677578262984753
# Test accuracy of the network on the 5000 test diagrams:    89.60 %
# Validation accuracy of the network on the 5000 test diagrams:    88.24 %
# epoch: 215 loss: 20.483208552002907
# Test accuracy of the network on the 5000 test diagrams:    89.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 216 loss: 19.791884057223797
# Test accuracy of the network on the 5000 test diagrams:    90.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 217 loss: 19.301412358880043
# Test accuracy of the network on the 5000 test diagrams:    90.76 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 218 loss: 18.459284976124763
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 219 loss: 18.854777567088604
# Test accuracy of the network on the 5000 test diagrams:    90.82 %
# Validation accuracy of the network on the 5000 test diagrams:    90.00 %
# epoch: 220 loss: 19.06963972747326
# Test accuracy of the network on the 5000 test diagrams:    87.90 %
# Validation accuracy of the network on the 5000 test diagrams:    88.04 %
# epoch: 221 loss: 18.45663122832775
# Test accuracy of the network on the 5000 test diagrams:    90.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 222 loss: 19.013088442385197
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 223 loss: 19.585248485207558
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 224 loss: 18.749309740960598
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 225 loss: 18.9384635835886
# Test accuracy of the network on the 5000 test diagrams:    89.88 %
# Validation accuracy of the network on the 5000 test diagrams:    88.48 %
# epoch: 226 loss: 19.159833528101444
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.88 %
# epoch: 227 loss: 21.213976740837097
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 228 loss: 20.68718659877777
# Test accuracy of the network on the 5000 test diagrams:    90.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 229 loss: 20.439529068768024
# Test accuracy of the network on the 5000 test diagrams:    88.40 %
# Validation accuracy of the network on the 5000 test diagrams:    87.86 %
# epoch: 230 loss: 20.121621750295162
# Test accuracy of the network on the 5000 test diagrams:    89.86 %
# Validation accuracy of the network on the 5000 test diagrams:    88.72 %
# epoch: 231 loss: 18.642522606998682
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 232 loss: 18.93931432068348
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 233 loss: 19.41828627884388
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 234 loss: 18.353571489453316
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 235 loss: 18.939943946897984
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 236 loss: 17.941476605832577
# Test accuracy of the network on the 5000 test diagrams:    91.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 237 loss: 18.40239456295967
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 238 loss: 18.302602469921112
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 239 loss: 19.17604151368141
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 240 loss: 18.392440997064114
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 241 loss: 19.81928986310959
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 242 loss: 18.558114670217037
# Test accuracy of the network on the 5000 test diagrams:    90.00 %
# Validation accuracy of the network on the 5000 test diagrams:    88.52 %
# epoch: 243 loss: 18.60763470083475
# Test accuracy of the network on the 5000 test diagrams:    90.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 244 loss: 18.322977647185326
# Test accuracy of the network on the 5000 test diagrams:    90.68 %
# Validation accuracy of the network on the 5000 test diagrams:    90.08 %
# epoch: 245 loss: 18.8971676081419
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.12 %
# epoch: 246 loss: 18.261985145509243
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 247 loss: 22.44919851049781
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 248 loss: 19.086355932056904
# Test accuracy of the network on the 5000 test diagrams:    89.80 %
# Validation accuracy of the network on the 5000 test diagrams:    88.92 %
# epoch: 249 loss: 18.78621368855238
# Test accuracy of the network on the 5000 test diagrams:    90.18 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 250 loss: 18.69442930072546
# Test accuracy of the network on the 5000 test diagrams:    91.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 251 loss: 19.36983446031809
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 252 loss: 18.802575394511223
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 253 loss: 19.496502123773098
# Test accuracy of the network on the 5000 test diagrams:    90.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 254 loss: 18.39374317973852
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 255 loss: 18.501954451203346
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 256 loss: 18.83871976286173
# Test accuracy of the network on the 5000 test diagrams:    89.82 %
# Validation accuracy of the network on the 5000 test diagrams:    88.72 %
# epoch: 257 loss: 19.511209227144718
# Test accuracy of the network on the 5000 test diagrams:    90.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.60 %
# epoch: 258 loss: 18.855346724390984
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 259 loss: 18.754793792963028
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 260 loss: 18.521114975214005
# Test accuracy of the network on the 5000 test diagrams:    91.04 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 261 loss: 18.978332951664925
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 262 loss: 18.273710511624813
# Test accuracy of the network on the 5000 test diagrams:    90.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 263 loss: 18.005694657564163
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 264 loss: 18.57561829686165
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 265 loss: 18.499602638185024
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    90.22 %
# epoch: 266 loss: 18.211635254323483
# Test accuracy of the network on the 5000 test diagrams:    91.20 %
# Validation accuracy of the network on the 5000 test diagrams:    90.34 %
# epoch: 267 loss: 17.52161207050085
# Test accuracy of the network on the 5000 test diagrams:    90.84 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 268 loss: 18.618972301483154
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.20 %
# epoch: 269 loss: 18.417613118886948
# Test accuracy of the network on the 5000 test diagrams:    90.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.20 %
# epoch: 270 loss: 18.581233821809292
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 271 loss: 19.23391566425562
# Test accuracy of the network on the 5000 test diagrams:    90.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 272 loss: 19.72324515134096
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 273 loss: 18.524751379154623
# Test accuracy of the network on the 5000 test diagrams:    90.76 %
# ...
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 468 loss: 17.529941461980343
# Test accuracy of the network on the 5000 test diagrams:    90.98 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 469 loss: 18.475673906505108
# Test accuracy of the network on the 5000 test diagrams:    91.04 %
# Validation accuracy of the network on the 5000 test diagrams:    90.00 %
# epoch: 470 loss: 17.453521476127207
# Test accuracy of the network on the 5000 test diagrams:    91.74 %
# Validation accuracy of the network on the 5000 test diagrams:    90.24 %
# epoch: 471 loss: 19.274157628417015
# Test accuracy of the network on the 5000 test diagrams:    82.36 %
# Validation accuracy of the network on the 5000 test diagrams:    80.28 %
# epoch: 472 loss: 20.165123268961906
# Test accuracy of the network on the 5000 test diagrams:    90.86 %
# Validation accuracy of the network on the 5000 test diagrams:    90.12 %
# epoch: 473 loss: 17.33971268683672
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 474 loss: 17.664737723767757
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 475 loss: 17.348007008433342
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 476 loss: 18.814955167472363
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    88.98 %
# epoch: 477 loss: 17.474711377173662
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    88.90 %
# epoch: 478 loss: 17.398714661598206
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 479 loss: 18.55273177474737
# Test accuracy of the network on the 5000 test diagrams:    91.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 480 loss: 17.720198467373848
# Test accuracy of the network on the 5000 test diagrams:    91.10 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 481 loss: 17.69080437719822
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 482 loss: 17.368433378636837
# Test accuracy of the network on the 5000 test diagrams:    91.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.10 %
# epoch: 483 loss: 23.283808633685112
# Test accuracy of the network on the 5000 test diagrams:    89.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 484 loss: 19.191601306200027
# Test accuracy of the network on the 5000 test diagrams:    90.96 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 485 loss: 19.02871559560299
# Test accuracy of the network on the 5000 test diagrams:    90.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 486 loss: 17.988117948174477
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 487 loss: 17.84792321920395
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 488 loss: 18.238463290035725
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 489 loss: 17.028686463832855
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 490 loss: 18.483322955667973
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 491 loss: 16.77350101619959
# Test accuracy of the network on the 5000 test diagrams:    90.98 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 492 loss: 18.241261661052704
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.06 %
# epoch: 493 loss: 18.538949705660343
# Test accuracy of the network on the 5000 test diagrams:    91.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 494 loss: 17.861273001879454
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    90.04 %
# epoch: 495 loss: 17.828996039927006
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 496 loss: 17.51791925728321
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 497 loss: 17.426639571785927
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 498 loss: 17.05529372394085
# Test accuracy of the network on the 5000 test diagrams:    91.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 499 loss: 17.48055111989379
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# [20.747889026999474,
#  20.65145505219698,
#  20.403223231434822,
#  22.15877155959606,
#  19.879891455173492,
#  19.693836897611618,
#  19.675016447901726,
#  19.363330580294132,
#  19.44016182422638,
#  18.9577427059412,
#  19.897639617323875,
#  20.536432534456253,
#  19.505483224987984,
#  19.21921593695879,
#  20.123308464884758,
#  19.498684279620647,
#  19.730875335633755,
#  19.30934865772724,
#  18.915795024484396,
#  20.589476868510246,
#  20.251872450113297,
#  19.54478994011879,
#  21.2074057161808,
#  19.810751482844353,
#  19.04927945137024,
#  19.38615544140339,
#  19.275047704577446,
#  19.48431959748268,
#  19.619800619781017,
#  19.519689172506332,
#  19.426263887435198,
#  20.351188600063324,
#  19.604546420276165,
#  20.618958920240402,
#  22.48147886991501,
#  25.309450939297676,
#  20.21900037676096,
#  19.108687222003937,
#  19.23652637563646,
#  19.176945492625237,
#  19.64499705284834,
#  18.67485513538122,
#  18.681979089975357,
#  19.130590957589447,
#  19.176518999040127,
#  19.152336910367012,
#  19.355161927640438,
#  18.850413415580988,
#  18.658433236181736,
#  19.136043176054955,
#  19.72250735014677,
#  19.370171554386616,
#  19.215360939502716,
#  20.086062289774418,
#  18.772899366915226,
#  19.01672700792551,
#  19.984723672270775,
#  19.432552695274353,
#  19.809822127223015,
#  19.935061760246754,
#  20.449982427060604,
#  19.347118861973286,
#  19.031611278653145,
#  20.24380374699831,
#  19.81159383058548,
#  19.64027851819992,
#  19.28117172420025,
#  19.473004579544067,
#  19.355512894690037,
#  19.629364907741547,
#  22.53117224574089,
#  19.71199019998312,
#  20.10910116136074,
#  19.95346738025546,
#  19.188880562782288,
#  23.70314695313573,
#  19.379848286509514,
#  19.02339281141758,
#  18.981436416506767,
#  19.77435465157032,
#  19.450620852410793,
#  19.458521619439125,
#  18.646914415061474,
#  18.047999314963818,
#  19.202477544546127,
#  19.152652107179165,
#  18.862824857234955,
#  20.531135834753513,
#  20.01679115742445,
#  19.53817232325673,
#  18.982172705233097,
#  19.522930532693863,
#  19.05940624512732,
#  19.14199759066105,
#  20.07527581602335,
#  19.5769202709198,
#  18.43622412532568,
#  18.407309643924236,
#  18.886694237589836,
#  23.336259230971336,
#  75.15317237377167,
#  30.441627621650696,
#  22.64421896636486,
#  21.74629235267639,
#  20.438878536224365,
#  21.395177632570267,
#  20.52278524171561,
#  20.38651465624571,
#  19.888123102486134,
#  19.95175191015005,
#  20.074973806738853,
#  20.042950816452503,
#  20.32078316807747,
#  19.858730606734753,
#  19.65034320577979,
#  19.56825517117977,
#  19.16908736526966,
#  19.065432101488113,
#  20.17322351783514,
#  19.768902353942394,
#  19.41501072049141,
#  19.52943103760481,
#  19.087099440395832,
#  18.947231575846672,
#  18.91526820510626,
#  22.232127279043198,
#  20.846785366535187,
#  19.55872804671526,
#  19.295034363865852,
#  20.030160948634148,
#  19.889808237552643,
#  19.032955832779408,
#  18.652519047260284,
#  18.65481685101986,
#  19.379982627928257,
#  18.92787417769432,
#  18.980670139193535,
#  19.06461938470602,
#  18.292036797851324,
#  18.51029296964407,
#  18.87052471935749,
#  18.801198296248913,
#  18.300055995583534,
#  19.298768222332,
#  19.15946315228939,
#  18.553878232836723,
#  19.482360631227493,
#  19.717759385704994,
#  18.381419360637665,
#  19.46101277321577,
#  18.644518613815308,
#  18.151390550658107,
#  18.61205697618425,
#  18.92248486727476,
#  18.108482838608325,
#  18.499680453911424,
#  19.071105778217316,
#  19.411020025610924,
#  19.176791951060295,
#  18.79061149759218,
#  19.054873637855053,
#  19.57502706348896,
#  19.130050502717495,
#  19.410554721951485,
#  20.077072247862816,
#  19.525215730071068,
#  19.625617001671344,
#  20.214459367096424,
#  18.992615941911936,
#  18.73714130371809,
#  18.579123876988888,
#  18.25071892887354,
#  18.298283524811268,
#  18.06216725707054,
#  18.775686532258987,
#  19.327721789479256,
#  19.52349530160427,
#  19.022172041237354,
#  19.088169530034065,
#  18.97410038113594,
#  19.099428728222847,
#  18.497783295810223,
#  18.807782545685768,
#  19.527277022600174,
#  19.33628150820732,
#  19.177831441164017,
#  18.51257561892271,
#  18.45180903468281,
#  18.194550059735775,
#  19.049149490892887,
#  19.516482021659613,
#  19.907648339867592,
#  18.591876413673162,
#  19.77905486524105,
#  19.427528388798237,
#  18.498423665761948,
#  18.459959499537945,
#  20.76567144691944,
#  18.899810649454594,
#  18.39121450483799,
#  19.154430359601974,
#  19.385520197451115,
#  18.324989780783653,
#  18.89291825145483,
#  19.488332100212574,
#  19.279757879674435,
#  18.383467730134726,
#  20.20944045484066,
#  18.437771789729595,
#  18.691356725990772,
#  18.809736743569374,
#  19.589019164443016,
#  18.66381562501192,
#  22.11755057424307,
#  20.677578262984753,
#  20.483208552002907,
#  19.791884057223797,
#  19.301412358880043,
#  18.459284976124763,
#  18.854777567088604,
#  19.06963972747326,
#  18.45663122832775,
#  19.013088442385197,
#  19.585248485207558,
#  18.749309740960598,
#  18.9384635835886,
#  19.159833528101444,
#  21.213976740837097,
#  20.68718659877777,
#  20.439529068768024,
#  20.121621750295162,
#  18.642522606998682,
#  18.93931432068348,
#  19.41828627884388,
#  18.353571489453316,
#  18.939943946897984,
#  17.941476605832577,
#  18.40239456295967,
#  18.302602469921112,
#  19.17604151368141,
#  18.392440997064114,
#  19.81928986310959,
#  18.558114670217037,
#  18.60763470083475,
#  18.322977647185326,
#  18.8971676081419,
#  18.261985145509243,
#  22.44919851049781,
#  19.086355932056904,
#  18.78621368855238,
#  18.69442930072546,
#  19.36983446031809,
#  18.802575394511223,
#  19.496502123773098,
#  18.39374317973852,
#  18.501954451203346,
#  18.83871976286173,
#  19.511209227144718,
#  18.855346724390984,
#  18.754793792963028,
#  18.521114975214005,
#  18.978332951664925,
#  18.273710511624813,
#  18.005694657564163,
#  18.57561829686165,
#  18.499602638185024,
#  18.211635254323483,
#  17.52161207050085,
#  18.618972301483154,
#  18.417613118886948,
#  18.581233821809292,
#  19.23391566425562,
#  19.72324515134096,
#  18.524751379154623,
#  18.38544139545411,
#  18.766720548272133,
#  19.365905925631523,
#  18.291696563363075,
#  18.552598506212234,
#  17.854719258844852,
#  18.309855200350285,
#  18.22171575576067,
#  18.157440751791,
#  18.450823694467545,
#  18.43215185403824,
#  19.10395280085504,
#  18.73341454565525,
#  18.207369446754456,
#  17.609863981604576,
#  18.85699074715376,
#  20.389901101589203,
#  21.189427256584167,
#  20.02218723297119,
#  18.743886444717646,
#  20.16805689036846,
#  19.142879158258438,
#  18.702634550631046,
#  18.31693896651268,
#  17.90104714781046,
#  18.470178559422493,
#  18.17702117562294,
#  18.452078871428967,
#  18.803050875663757,
#  18.784210063517094,
#  18.088575860485435,
#  17.651321932673454,
#  17.9427403062582,
#  18.140495359897614,
#  18.43074558675289,
#  17.745332427322865,
#  17.491169799119234,
#  17.65933609381318,
#  18.015743479132652,
#  18.384626477956772,
#  17.778256729245186,
#  18.980540186166763,
#  18.637352772057056,
#  17.578181624412537,
#  18.39509680867195,
#  18.601316206157207,
#  18.89065845310688,
#  18.17908474802971,
#  18.775361351668835,
#  18.074724078178406,
#  19.76119653880596,
#  24.809110961854458,
#  20.21743393689394,
#  19.3030214458704,
#  18.511384405195713,
#  17.993426613509655,
#  18.35368800163269,
#  18.89242108911276,
#  18.210813902318478,
#  18.19181916117668,
#  17.88386544585228,
#  17.744514659047127,
#  18.20594785362482,
#  18.05932030081749,
#  18.602093666791916,
#  17.79313502460718,
#  17.81219893693924,
#  18.120099671185017,
#  19.944199196994305,
#  18.25086972117424,
#  18.361889585852623,
#  20.47710433602333,
#  19.03995256870985,
#  18.537308789789677,
#  19.858837462961674,
#  18.164794899523258,
#  18.77145268023014,
#  17.65414777956903,
#  18.2250504642725,
#  18.716147765517235,
#  19.297931112349033,
#  18.040150851011276,
#  18.73383954912424,
#  17.701339915394783,
#  17.62690931558609,
#  17.919432617723942,
#  18.69040387123823,
#  17.95551265962422,
#  17.861124731600285,
#  18.63502413779497,
#  17.486227974295616,
#  17.88176341354847,
#  19.139807552099228,
#  18.07024420425296,
#  17.55904222279787,
#  17.543084733188152,
#  19.118074245750904,
#  18.71910537034273,
#  18.00237262248993,
#  19.013342954218388,
#  18.50246860086918,
#  17.361378982663155,
#  17.657096210867167,
#  17.776838552206755,
#  18.071385256014764,
#  17.371812030673027,
#  18.749385185539722,
#  17.787607330828905,
#  18.625953063368797,
#  18.849583633244038,
#  19.210271324962378,
#  18.381458088755608,
#  18.232472486793995,
#  17.835412427783012,
#  17.44365318119526,
#  18.637992784380913,
#  17.583954487927258,
#  18.287553295493126,
#  18.43078427016735,
#  17.218694742769003,
#  17.5310168415308,
#  18.10367016494274,
#  17.78595209121704,
#  18.617148101329803,
#  24.560194201767445,
#  23.937027484178543,
#  20.013905830681324,
#  18.495769001543522,
#  18.4250253662467,
#  18.379078179597855,
#  18.217043660581112,
#  18.536439463496208,
#  17.923882842063904,
#  18.86794652044773,
#  17.428398232907057,
#  17.54706570506096,
#  17.66737088561058,
#  17.71494323760271,
#  17.327346958220005,
#  18.799733098130673,
#  18.207805685698986,
#  17.504229061305523,
#  17.457976050674915,
#  17.89248848706484,
#  17.763951800763607,
#  17.712758496403694,
#  17.69093870744109,
#  17.959928587079048,
#  18.835746429860592,
#  17.8395382091403,
#  18.322469972074032,
#  17.808685697615147,
#  17.39831894636154,
#  17.154714815318584,
#  17.549970537424088,
#  17.000709298998117,
#  17.63869959115982,
#  18.491369493305683,
#  18.2091708406806,
#  18.233621075749397,
#  18.521266885101795,
#  18.768133841454983,
#  17.792019203305244,
#  17.785540871322155,
#  18.427774051204324,
#  17.673348605632782,
#  18.121013708412647,
#  18.72901331074536,
#  18.472206510603428,
#  17.92504369840026,
#  17.923091769218445,
#  21.67438594996929,
#  18.173204437829554,
#  17.963995218276978,
#  18.009650573134422,
#  18.48608322441578,
#  18.724187575280666,
#  17.641849860548973,
#  18.127107582986355,
#  17.805502086877823,
#  17.68950305134058,
#  17.552525468170643,
#  18.456909209489822,
#  18.47541034221649,
#  21.255734607577324,
#  18.468469716608524,
#  18.162393428385258,
#  17.90292187780142,
#  20.32494557648897,
#  18.40751842345344,
#  17.766925387084484,
#  17.422184340655804,
#  17.76049192994833,
#  17.374301817268133,
#  17.529941461980343,
#  18.475673906505108,
#  17.453521476127207,
#  19.274157628417015,
#  20.165123268961906,
#  17.33971268683672,
#  17.664737723767757,
#  17.348007008433342,
#  18.814955167472363,
#  17.474711377173662,
#  17.398714661598206,
#  18.55273177474737,
#  17.720198467373848,
#  17.69080437719822,
#  17.368433378636837,
#  23.283808633685112,
#  19.191601306200027,
#  19.02871559560299,
#  17.988117948174477,
#  17.84792321920395,
#  18.238463290035725,
#  17.028686463832855,
#  18.483322955667973,
#  16.77350101619959,
#  18.241261661052704,
#  18.538949705660343,
#  17.861273001879454,
#  17.828996039927006,
#  17.51791925728321,
#  17.426639571785927,
#  17.05529372394085,
#  17.48055111989379]

# %%
train(model, num_epochs=1000, verbose=True, compute_accuracy=True)
# Out:
# epoch: 0 loss: 18.68181872367859
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 1 loss: 18.330043144524097
# Test accuracy of the network on the 5000 test diagrams:    90.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 2 loss: 19.28436778485775
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 3 loss: 18.061810217797756
# Test accuracy of the network on the 5000 test diagrams:    91.18 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 4 loss: 17.87944643944502
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 5 loss: 17.6191086769104
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 6 loss: 18.311734341084957
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 7 loss: 17.05963969603181
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 8 loss: 17.628943495452404
# Test accuracy of the network on the 5000 test diagrams:    91.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 9 loss: 17.245839558541775
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 10 loss: 17.562298238277435
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 11 loss: 17.462227910757065
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    88.50 %
# epoch: 12 loss: 17.176584765315056
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 13 loss: 18.285200849175453
# Test accuracy of the network on the 5000 test diagrams:    89.42 %
# Validation accuracy of the network on the 5000 test diagrams:    87.44 %
# epoch: 14 loss: 19.135272450745106
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 15 loss: 17.906792253255844
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 16 loss: 17.76672887802124
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 17 loss: 17.70033737272024
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 18 loss: 16.88003856688738
# Test accuracy of the network on the 5000 test diagrams:    91.18 %
# Validation accuracy of the network on the 5000 test diagrams:    88.82 %
# epoch: 19 loss: 17.810865305364132
# Test accuracy of the network on the 5000 test diagrams:    90.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 20 loss: 19.33152650296688
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    87.76 %
# epoch: 21 loss: 18.666417255997658
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.76 %
# epoch: 22 loss: 20.740852624177933
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.94 %
# epoch: 23 loss: 20.29256295412779
# Test accuracy of the network on the 5000 test diagrams:    90.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 24 loss: 18.2685016207397
# Test accuracy of the network on the 5000 test diagrams:    90.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.12 %
# epoch: 25 loss: 19.683459036052227
# Test accuracy of the network on the 5000 test diagrams:    90.40 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 26 loss: 18.2776050940156
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 27 loss: 18.257142335176468
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 28 loss: 18.91193963587284
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 29 loss: 17.198031790554523
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 30 loss: 17.120909743010998
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 31 loss: 17.028670977801085
# Test accuracy of the network on the 5000 test diagrams:    91.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 32 loss: 16.91852919012308
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 33 loss: 17.92180158942938
# Test accuracy of the network on the 5000 test diagrams:    91.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 34 loss: 17.301422387361526
# Test accuracy of the network on the 5000 test diagrams:    91.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 35 loss: 16.61455252021551
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 36 loss: 16.49785903841257
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    88.00 %
# epoch: 37 loss: 17.12296025827527
# Test accuracy of the network on the 5000 test diagrams:    91.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 38 loss: 16.72590810060501
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.90 %
# epoch: 39 loss: 19.384755924344063
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    88.74 %
# epoch: 40 loss: 18.089010879397392
# Test accuracy of the network on the 5000 test diagrams:    91.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 41 loss: 17.03401467949152
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.72 %
# epoch: 42 loss: 17.19496551156044
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    88.94 %
# epoch: 43 loss: 17.775548689067364
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 44 loss: 17.73507310450077
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    88.92 %
# epoch: 45 loss: 17.528308667242527
# Test accuracy of the network on the 5000 test diagrams:    91.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 46 loss: 17.368660405278206
# Test accuracy of the network on the 5000 test diagrams:    91.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 47 loss: 17.564346335828304
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    88.92 %
# epoch: 48 loss: 17.327013848349452
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 49 loss: 18.009168550372124
# Test accuracy of the network on the 5000 test diagrams:    89.94 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 50 loss: 18.258909810334444
# Test accuracy of the network on the 5000 test diagrams:    91.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.88 %
# epoch: 51 loss: 17.912146240472794
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 52 loss: 17.547801338136196
# Test accuracy of the network on the 5000 test diagrams:    91.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 53 loss: 17.445308163762093
# Test accuracy of the network on the 5000 test diagrams:    90.62 %
# Validation accuracy of the network on the 5000 test diagrams:    88.44 %
# epoch: 54 loss: 18.786016944795847
# Test accuracy of the network on the 5000 test diagrams:    91.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 55 loss: 17.978089556097984
# Test accuracy of the network on the 5000 test diagrams:    87.02 %
# Validation accuracy of the network on the 5000 test diagrams:    86.46 %
# epoch: 56 loss: 20.536343194544315
# Test accuracy of the network on the 5000 test diagrams:    90.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 57 loss: 17.66556106507778
# Test accuracy of the network on the 5000 test diagrams:    91.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 58 loss: 17.453886575996876
# Test accuracy of the network on the 5000 test diagrams:    90.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 59 loss: 17.866792805492878
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 60 loss: 18.011697463691235
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 61 loss: 17.272349666804075
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    90.04 %
# epoch: 62 loss: 17.260881014168262
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 63 loss: 17.623529836535454
# Test accuracy of the network on the 5000 test diagrams:    90.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.52 %
# epoch: 64 loss: 17.11278159171343
# Test accuracy of the network on the 5000 test diagrams:    90.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 65 loss: 17.86417680978775
# Test accuracy of the network on the 5000 test diagrams:    90.96 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 66 loss: 17.119784384965897
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 67 loss: 18.138982616364956
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 68 loss: 17.181179977953434
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 69 loss: 18.04025575518608
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    88.62 %
# epoch: 70 loss: 17.320542596280575
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 71 loss: 17.61714866757393
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 72 loss: 17.388312205672264
# Test accuracy of the network on the 5000 test diagrams:    91.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.96 %
# epoch: 73 loss: 17.53557773679495
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 74 loss: 17.064303413033485
# Test accuracy of the network on the 5000 test diagrams:    91.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.12 %
# epoch: 75 loss: 17.03122029453516
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 76 loss: 18.612191662192345
# Test accuracy of the network on the 5000 test diagrams:    89.84 %
# Validation accuracy of the network on the 5000 test diagrams:    88.52 %
# epoch: 77 loss: 32.97079895436764
# Test accuracy of the network on the 5000 test diagrams:    81.76 %
# Validation accuracy of the network on the 5000 test diagrams:    79.72 %
# epoch: 78 loss: 26.492850944399834
# Test accuracy of the network on the 5000 test diagrams:    90.44 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 79 loss: 20.01273686438799
# Test accuracy of the network on the 5000 test diagrams:    89.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 80 loss: 19.133994594216347
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 81 loss: 18.778213374316692
# Test accuracy of the network on the 5000 test diagrams:    90.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 82 loss: 18.25038803368807
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 83 loss: 17.52269348502159
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 84 loss: 17.84606920927763
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 85 loss: 18.260145612061024
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 86 loss: 17.5343710295856
# Test accuracy of the network on the 5000 test diagrams:    90.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 87 loss: 17.668231420218945
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 88 loss: 18.89507845789194
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 89 loss: 17.47764676064253
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 90 loss: 18.041292645037174
# Test accuracy of the network on the 5000 test diagrams:    90.88 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 91 loss: 17.487937442958355
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.92 %
# epoch: 92 loss: 17.031515263020992
# Test accuracy of the network on the 5000 test diagrams:    90.38 %
# Validation accuracy of the network on the 5000 test diagrams:    88.74 %
# epoch: 93 loss: 16.676685713231564
# Test accuracy of the network on the 5000 test diagrams:    91.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 94 loss: 17.464732356369495
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 95 loss: 16.80164085328579
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 96 loss: 17.071215510368347
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 97 loss: 17.112013585865498
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 98 loss: 17.316043724305928
# Test accuracy of the network on the 5000 test diagrams:    91.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 99 loss: 16.949319828301668
# Test accuracy of the network on the 5000 test diagrams:    91.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 100 loss: 17.00652739405632
# Test accuracy of the network on the 5000 test diagrams:    90.98 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 101 loss: 17.516899783164263
# Test accuracy of the network on the 5000 test diagrams:    91.52 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 102 loss: 16.966579172760248
# Test accuracy of the network on the 5000 test diagrams:    91.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 103 loss: 17.114917159080505
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 104 loss: 17.056498900055885
# Test accuracy of the network on the 5000 test diagrams:    91.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 105 loss: 16.78514202684164
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 106 loss: 17.024939343333244
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 107 loss: 17.221545346081257
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 108 loss: 16.701519057154655
# Test accuracy of the network on the 5000 test diagrams:    91.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 109 loss: 17.10445585846901
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 110 loss: 17.20926348119974
# Test accuracy of the network on the 5000 test diagrams:    91.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 111 loss: 17.766465861350298
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 112 loss: 17.319379523396492
# Test accuracy of the network on the 5000 test diagrams:    90.08 %
# Validation accuracy of the network on the 5000 test diagrams:    88.80 %
# epoch: 113 loss: 18.11091646552086
# Test accuracy of the network on the 5000 test diagrams:    91.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 114 loss: 17.61269722878933
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 115 loss: 17.88253496028483
# Test accuracy of the network on the 5000 test diagrams:    91.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.20 %
# epoch: 116 loss: 17.910812631249428
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    88.68 %
# epoch: 117 loss: 17.796923130750656
# Test accuracy of the network on the 5000 test diagrams:    91.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 118 loss: 17.520587414503098
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 119 loss: 18.058420814573765
# Test accuracy of the network on the 5000 test diagrams:    90.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 120 loss: 18.015591993927956
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 121 loss: 17.765631310641766
# Test accuracy of the network on the 5000 test diagrams:    90.72 %
# Validation accuracy of the network on the 5000 test diagrams:    90.26 %
# epoch: 122 loss: 17.443961650133133
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.10 %
# epoch: 123 loss: 17.429239377379417
# Test accuracy of the network on the 5000 test diagrams:    90.86 %
# Validation accuracy of the network on the 5000 test diagrams:    88.24 %
# epoch: 124 loss: 18.10950818285346
# Test accuracy of the network on the 5000 test diagrams:    91.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 125 loss: 17.282302118837833
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 126 loss: 17.35326100513339
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.96 %
# epoch: 127 loss: 18.485566414892673
# Test accuracy of the network on the 5000 test diagrams:    90.48 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 128 loss: 16.982810143381357
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    90.28 %
# epoch: 129 loss: 16.614583428949118
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 130 loss: 17.937540344893932
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 131 loss: 17.450793309137225
# Test accuracy of the network on the 5000 test diagrams:    90.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 132 loss: 17.435905829072
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 133 loss: 17.727167956531048
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 134 loss: 17.350276628509164
# Test accuracy of the network on the 5000 test diagrams:    90.16 %
# Validation accuracy of the network on the 5000 test diagrams:    88.20 %
# epoch: 135 loss: 17.385954342782497
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 136 loss: 19.204180594533682
# Test accuracy of the network on the 5000 test diagrams:    90.96 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 137 loss: 17.865174748003483
# Test accuracy of the network on the 5000 test diagrams:    91.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 138 loss: 18.356329940259457
# Test accuracy of the network on the 5000 test diagrams:    90.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 139 loss: 17.978520430624485
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 140 loss: 16.969216112047434
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 141 loss: 17.62944955378771
# Test accuracy of the network on the 5000 test diagrams:    91.80 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 142 loss: 17.813669480383396
# Test accuracy of the network on the 5000 test diagrams:    90.90 %
# Validation accuracy of the network on the 5000 test diagrams:    88.58 %
# epoch: 143 loss: 17.121519830077887
# Test accuracy of the network on the 5000 test diagrams:    91.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.56 %
# epoch: 144 loss: 17.9791152253747
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 145 loss: 17.554093247279525
# Test accuracy of the network on the 5000 test diagrams:    91.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 146 loss: 16.764899250119925
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 147 loss: 17.174018688499928
# Test accuracy of the network on the 5000 test diagrams:    91.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 148 loss: 17.196960508823395
# Test accuracy of the network on the 5000 test diagrams:    91.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 149 loss: 16.56888358667493
# Test accuracy of the network on the 5000 test diagrams:    92.04 %
# Validation accuracy of the network on the 5000 test diagrams:    90.00 %
# epoch: 150 loss: 16.766545958817005
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 151 loss: 17.336638778448105
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 152 loss: 18.355439752340317
# Test accuracy of the network on the 5000 test diagrams:    91.04 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 153 loss: 16.999942414462566
# Test accuracy of the network on the 5000 test diagrams:    91.18 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 154 loss: 17.174556523561478
# Test accuracy of the network on the 5000 test diagrams:    91.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.10 %
# epoch: 155 loss: 18.17184930294752
# Test accuracy of the network on the 5000 test diagrams:    90.84 %
# Validation accuracy of the network on the 5000 test diagrams:    88.60 %
# epoch: 156 loss: 17.220018707215786
# Test accuracy of the network on the 5000 test diagrams:    91.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 157 loss: 18.359807647764683
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    88.76 %
# epoch: 158 loss: 17.770034462213516
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.04 %
# epoch: 159 loss: 18.006476052105427
# Test accuracy of the network on the 5000 test diagrams:    91.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 160 loss: 16.767092547379434
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 161 loss: 17.097351148724556
# Test accuracy of the network on the 5000 test diagrams:    90.76 %
# Validation accuracy of the network on the 5000 test diagrams:    88.82 %
# epoch: 162 loss: 17.283054791390896
# Test accuracy of the network on the 5000 test diagrams:    91.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 163 loss: 17.480986170470715
# Test accuracy of the network on the 5000 test diagrams:    91.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 164 loss: 17.466540314257145
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 165 loss: 16.421083569526672
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.12 %
# epoch: 166 loss: 17.19661722332239
# Test accuracy of the network on the 5000 test diagrams:    91.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.74 %
# epoch: 167 loss: 17.18266324698925
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    90.04 %
# epoch: 168 loss: 17.264040045440197
# Test accuracy of the network on the 5000 test diagrams:    91.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 169 loss: 17.624116346240044
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 170 loss: 19.69016993790865
# Test accuracy of the network on the 5000 test diagrams:    90.28 %
# Validation accuracy of the network on the 5000 test diagrams:    88.64 %
# epoch: 171 loss: 18.166665457189083
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 172 loss: 17.5966091491282
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 173 loss: 17.37840034812689
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 174 loss: 17.243698306381702
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 175 loss: 17.03308690339327
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 176 loss: 18.80274334177375
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    88.94 %
# epoch: 177 loss: 16.965701542794704
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 178 loss: 17.1371636018157
# Test accuracy of the network on the 5000 test diagrams:    90.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.96 %
# epoch: 179 loss: 18.11264407634735
# Test accuracy of the network on the 5000 test diagrams:    91.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 180 loss: 17.455972254276276
# Test accuracy of the network on the 5000 test diagrams:    90.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 181 loss: 17.505621396005154
# Test accuracy of the network on the 5000 test diagrams:    90.88 %
# Validation accuracy of the network on the 5000 test diagrams:    88.64 %
# epoch: 182 loss: 19.075915470719337
# Test accuracy of the network on the 5000 test diagrams:    90.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.32 %
# epoch: 183 loss: 18.411608032882214
# Test accuracy of the network on the 5000 test diagrams:    91.20 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 184 loss: 16.825659975409508
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.54 %
# epoch: 185 loss: 17.20886640250683
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 186 loss: 17.611437864601612
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 187 loss: 16.491325348615646
# Test accuracy of the network on the 5000 test diagrams:    91.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.78 %
# epoch: 188 loss: 17.612646736204624
# Test accuracy of the network on the 5000 test diagrams:    89.40 %
# Validation accuracy of the network on the 5000 test diagrams:    88.32 %
# epoch: 189 loss: 18.259416840970516
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 190 loss: 18.112848110496998
# Test accuracy of the network on the 5000 test diagrams:    90.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 191 loss: 17.29651341587305
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 192 loss: 16.791187673807144
# Test accuracy of the network on the 5000 test diagrams:    91.18 %
# Validation accuracy of the network on the 5000 test diagrams:    88.06 %
# epoch: 193 loss: 16.857636395841837
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 194 loss: 17.16500425338745
# Test accuracy of the network on the 5000 test diagrams:    90.34 %
# Validation accuracy of the network on the 5000 test diagrams:    88.56 %
# epoch: 195 loss: 18.309677556157112
# Test accuracy of the network on the 5000 test diagrams:    91.90 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 196 loss: 16.981319166719913
# Test accuracy of the network on the 5000 test diagrams:    90.32 %
# Validation accuracy of the network on the 5000 test diagrams:    88.42 %
# epoch: 197 loss: 17.491191640496254
# Test accuracy of the network on the 5000 test diagrams:    90.96 %
# Validation accuracy of the network on the 5000 test diagrams:    88.28 %
# epoch: 198 loss: 20.822089575231075
# Test accuracy of the network on the 5000 test diagrams:    88.92 %
# Validation accuracy of the network on the 5000 test diagrams:    86.92 %
# epoch: 199 loss: 18.123499751091003
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.56 %
# epoch: 200 loss: 17.47719369828701
# Test accuracy of the network on the 5000 test diagrams:    91.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 201 loss: 17.580754943192005
# Test accuracy of the network on the 5000 test diagrams:    91.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 202 loss: 16.86865720897913
# Test accuracy of the network on the 5000 test diagrams:    91.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 203 loss: 16.653562612831593
# Test accuracy of the network on the 5000 test diagrams:    91.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 204 loss: 17.152393840253353
# Test accuracy of the network on the 5000 test diagrams:    91.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.80 %
# epoch: 205 loss: 16.903268218040466
# Test accuracy of the network on the 5000 test diagrams:    91.88 %
# Validation accuracy of the network on the 5000 test diagrams:    89.90 %
# epoch: 206 loss: 16.93645476642996
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.06 %
# epoch: 207 loss: 16.94707289338112
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    90.26 %
# epoch: 208 loss: 16.679708786308765
# Test accuracy of the network on the 5000 test diagrams:    91.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 209 loss: 16.723386235535145
# Test accuracy of the network on the 5000 test diagrams:    91.94 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 210 loss: 17.038418661803007
# Test accuracy of the network on the 5000 test diagrams:    91.50 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 211 loss: 17.973220258951187
# Test accuracy of the network on the 5000 test diagrams:    91.50 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 212 loss: 18.14545225352049
# Test accuracy of the network on the 5000 test diagrams:    90.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 213 loss: 17.93852792493999
# Test accuracy of the network on the 5000 test diagrams:    90.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 214 loss: 17.20120418071747
# Test accuracy of the network on the 5000 test diagrams:    90.94 %
# Validation accuracy of the network on the 5000 test diagrams:    88.66 %
# epoch: 215 loss: 17.85920212417841
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 216 loss: 18.459862530231476
# Test accuracy of the network on the 5000 test diagrams:    91.10 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 217 loss: 16.713968984782696
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    88.84 %
# epoch: 218 loss: 17.113348059356213
# Test accuracy of the network on the 5000 test diagrams:    90.84 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 219 loss: 17.238462045788765
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.66 %
# epoch: 220 loss: 17.217568084597588
# Test accuracy of the network on the 5000 test diagrams:    91.96 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 221 loss: 16.533386141061783
# Test accuracy of the network on the 5000 test diagrams:    91.40 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 222 loss: 16.722047179937363
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 223 loss: 16.58402293175459
# Test accuracy of the network on the 5000 test diagrams:    92.14 %
# Validation accuracy of the network on the 5000 test diagrams:    89.48 %
# epoch: 224 loss: 17.365119494497776
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    88.66 %
# epoch: 225 loss: 17.643147461116314
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.04 %
# epoch: 226 loss: 17.668220534920692
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.86 %
# epoch: 227 loss: 17.826962873339653
# Test accuracy of the network on the 5000 test diagrams:    91.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 228 loss: 16.42315273731947
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    88.52 %
# epoch: 229 loss: 16.974973395466805
# Test accuracy of the network on the 5000 test diagrams:    90.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.86 %
# epoch: 230 loss: 19.433899998664856
# Test accuracy of the network on the 5000 test diagrams:    91.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.22 %
# epoch: 231 loss: 17.539236824959517
# Test accuracy of the network on the 5000 test diagrams:    90.80 %
# Validation accuracy of the network on the 5000 test diagrams:    88.74 %
# epoch: 232 loss: 16.98478217050433
# Test accuracy of the network on the 5000 test diagrams:    91.28 %
# Validation accuracy of the network on the 5000 test diagrams:    89.46 %
# epoch: 233 loss: 17.48613929003477
# Test accuracy of the network on the 5000 test diagrams:    91.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 234 loss: 16.82947525382042
# Test accuracy of the network on the 5000 test diagrams:    91.22 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 235 loss: 16.719232968986034
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.90 %
# epoch: 236 loss: 16.629842095077038
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 237 loss: 16.484225124120712
# Test accuracy of the network on the 5000 test diagrams:    91.78 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 238 loss: 16.43098515132442
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 239 loss: 17.091238752007484
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.88 %
# epoch: 240 loss: 17.343461267650127
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.28 %
# epoch: 241 loss: 18.782475531101227
# Test accuracy of the network on the 5000 test diagrams:    90.86 %
# Validation accuracy of the network on the 5000 test diagrams:    89.14 %
# epoch: 242 loss: 17.395948201417923
# Test accuracy of the network on the 5000 test diagrams:    91.24 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 243 loss: 17.986702986061573
# Test accuracy of the network on the 5000 test diagrams:    91.68 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 244 loss: 18.678502172231674
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    88.70 %
# epoch: 245 loss: 17.061486922204494
# Test accuracy of the network on the 5000 test diagrams:    91.44 %
# Validation accuracy of the network on the 5000 test diagrams:    89.26 %
# epoch: 246 loss: 20.459557853639126
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.24 %
# epoch: 247 loss: 17.899872712790966
# Test accuracy of the network on the 5000 test diagrams:    91.02 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 248 loss: 16.748887427151203
# Test accuracy of the network on the 5000 test diagrams:    91.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.10 %
# epoch: 249 loss: 16.71679477393627
# Test accuracy of the network on the 5000 test diagrams:    91.64 %
# Validation accuracy of the network on the 5000 test diagrams:    89.70 %
# epoch: 250 loss: 16.41039030253887
# Test accuracy of the network on the 5000 test diagrams:    91.26 %
# Validation accuracy of the network on the 5000 test diagrams:    89.38 %
# epoch: 251 loss: 16.417934846132994
# Test accuracy of the network on the 5000 test diagrams:    91.10 %
# Validation accuracy of the network on the 5000 test diagrams:    88.66 %
# epoch: 252 loss: 16.689981393516064
# Test accuracy of the network on the 5000 test diagrams:    91.58 %
# Validation accuracy of the network on the 5000 test diagrams:    89.30 %
# epoch: 253 loss: 15.954275283962488
# Test accuracy of the network on the 5000 test diagrams:    91.56 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 254 loss: 16.934438325464725
# Test accuracy of the network on the 5000 test diagrams:    92.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.94 %
# epoch: 255 loss: 17.12631505727768
# Test accuracy of the network on the 5000 test diagrams:    91.08 %
# Validation accuracy of the network on the 5000 test diagrams:    89.44 %
# epoch: 256 loss: 16.50532465428114
# Test accuracy of the network on the 5000 test diagrams:    91.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.60 %
# epoch: 257 loss: 17.162594821304083
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.44 %
# epoch: 258 loss: 17.211410775780678
# Test accuracy of the network on the 5000 test diagrams:    90.92 %
# Validation accuracy of the network on the 5000 test diagrams:    88.80 %
# epoch: 259 loss: 17.72724625840783
# Test accuracy of the network on the 5000 test diagrams:    91.32 %
# Validation accuracy of the network on the 5000 test diagrams:    89.08 %
# epoch: 260 loss: 16.87353476881981
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 261 loss: 17.348558194935322
# Test accuracy of the network on the 5000 test diagrams:    91.92 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 262 loss: 16.692178085446358
# Test accuracy of the network on the 5000 test diagrams:    91.84 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 263 loss: 16.154429078102112
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    88.86 %
# epoch: 264 loss: 17.421699784696102
# Test accuracy of the network on the 5000 test diagrams:    91.34 %
# Validation accuracy of the network on the 5000 test diagrams:    89.00 %
# epoch: 265 loss: 16.712891444563866
# Test accuracy of the network on the 5000 test diagrams:    91.48 %
# Validation accuracy of the network on the 5000 test diagrams:    89.72 %
# epoch: 266 loss: 16.421695321798325
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    88.54 %
# epoch: 267 loss: 17.11955051869154
# Test accuracy of the network on the 5000 test diagrams:    91.60 %
# Validation accuracy of the network on the 5000 test diagrams:    88.82 %
# epoch: 268 loss: 16.742400731891394
# Test accuracy of the network on the 5000 test diagrams:    91.84 %
# Validation accuracy of the network on the 5000 test diagrams:    90.24 %
# epoch: 269 loss: 17.463183291256428
# Test accuracy of the network on the 5000 test diagrams:    90.74 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 270 loss: 17.272154070436954
# Test accuracy of the network on the 5000 test diagrams:    91.62 %
# Validation accuracy of the network on the 5000 test diagrams:    89.66 %
# epoch: 271 loss: 16.674169413745403
# Test accuracy of the network on the 5000 test diagrams:    91.76 %
# Validation accuracy of the network on the 5000 test diagrams:    89.50 %
# epoch: 272 loss: 16.44212408363819
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    90.34 %
# epoch: 273 loss: 16.693767726421356
# Test accuracy of the network on the 5000 test diagrams:    91.46 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 274 loss: 17.051139317452908
# Test accuracy of the network on the 5000 test diagrams:    91.06 %
# Validation accuracy of the network on the 5000 test diagrams:    88.38 %
# epoch: 275 loss: 16.86932659894228
# Test accuracy of the network on the 5000 test diagrams:    92.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.98 %
# epoch: 276 loss: 17.647516064345837
# Test accuracy of the network on the 5000 test diagrams:    91.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 277 loss: 17.280258115381002
# Test accuracy of the network on the 5000 test diagrams:    91.72 %
# Validation accuracy of the network on the 5000 test diagrams:    89.02 %
# epoch: 278 loss: 16.957735136151314
# Test accuracy of the network on the 5000 test diagrams:    91.42 %
# Validation accuracy of the network on the 5000 test diagrams:    89.64 %
# epoch: 279 loss: 16.285982944071293
# Test accuracy of the network on the 5000 test diagrams:    92.16 %
# Validation accuracy of the network on the 5000 test diagrams:    89.36 %
# epoch: 280 loss: 17.17901249602437
# Test accuracy of the network on the 5000 test diagrams:    91.38 %
# Validation accuracy of the network on the 5000 test diagrams:    89.34 %
# epoch: 281 loss: 16.70543923974037
# Test accuracy of the network on the 5000 test diagrams:    91.54 %
# Validation accuracy of the network on the 5000 test diagrams:    89.18 %
# epoch: 282 loss: 16.057275729253888
# Test accuracy of the network on the 5000 test diagrams:    91.60 %
# Validation accuracy of the network on the 5000 test diagrams:    89.20 %
# epoch: 283 loss: 16.65032623708248
# Test accuracy of the network on the 5000 test diagrams:    91.76 %
# Validation accuracy of the network on the 5000 test diagrams:    89.68 %
# epoch: 284 loss: 17.152313247323036
# Test accuracy of the network on the 5000 test diagrams:    91.12 %
# Validation accuracy of the network on the 5000 test diagrams:    89.04 %
# epoch: 285 loss: 16.93833038210869
# Test accuracy of the network on the 5000 test diagrams:    91.30 %
# Validation accuracy of the network on the 5000 test diagrams:    89.62 %
# epoch: 286 loss: 25.409245274960995
# Test accuracy of the network on the 5000 test diagrams:    87.46 %
# Validation accuracy of the network on the 5000 test diagrams:    86.32 %
# epoch: 287 loss: 21.268649391829967
# Test accuracy of the network on the 5000 test diagrams:    91.36 %
# Validation accuracy of the network on the 5000 test diagrams:    89.42 %
# epoch: 288 loss: 18.75564505159855
# Test accuracy of the network on the 5000 test diagrams:    90.76 %
# Validation accuracy of the network on the 5000 test diagrams:    88.96 %
# epoch: 289 loss: 20.068403005599976
# Test accuracy of the network on the 5000 test diagrams:    90.36 %
# Validation accuracy of the network on the 5000 test diagrams:    88.00 %
# epoch: 290 loss: 18.153085373342037
# Test accuracy of the network on the 5000 test diagrams:    91.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.76 %
# epoch: 291 loss: 17.132578887045383
# Test accuracy of the network on the 5000 test diagrams:    91.88 %
# Validation accuracy of the network on the 5000 test diagrams:    89.40 %
# epoch: 292 loss: 17.248583022505045
# Test accuracy of the network on the 5000 test diagrams:    91.66 %
# Validation accuracy of the network on the 5000 test diagrams:    89.82 %
# epoch: 293 loss: 16.59349548816681
# Test accuracy of the network on the 5000 test diagrams:    91.82 %
# Validation accuracy of the network on the 5000 test diagrams:    89.16 %
# epoch: 294 loss: 15.977474398911
# Test accuracy of the network on the 5000 test diagrams:    91.96 %
# Validation accuracy of the network on the 5000 test diagrams:    90.02 %
# epoch: 295 loss: 16.13258196413517
# Test accuracy of the network on the 5000 test diagrams:    91.70 %
# Validation accuracy of the network on the 5000 test diagrams:    89.58 %
# epoch: 296 loss: 17.755585730075836
# Test accuracy of the network on the 5000 test diagrams:    91.00 %
# Validation accuracy of the network on the 5000 test diagrams:    89.32 %
# epoch: 297 loss: 18.847684122622013
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2a5eeaea7eaf> in <module>
# ----> 1 train(model, num_epochs=1000, verbose=True, compute_accuracy=True)
#
# <ipython-input-17-9671896eded1> in train(model, num_epochs, lr, verbose, compute_accuracy)
#      38                     _, predictions = torch.max(outputs, 1)
#      39                     total += y_batch.size(0)
# ---> 40                     correct += (predictions == y_batch).sum().item()
#      41
#      42             print('Test accuracy of the network on the 5000 test diagrams: %8.2f %%' % (
#
# KeyboardInterrupt:

# %%
torch.save(model, 'PersFormer_ORBIT5K.pth')

# %%
torch.save(model.state_dict(), 'PersFormer_ORBIT5K_state_dict.pth')

# %%
# Out:
# number of trainable parameters: 291589

# %%
correct = 0
total = 0

with torch.no_grad():
    for x_batch, y_batch in dataloader_validation:
        if use_cuda:
                x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
        outputs = model(x_batch).squeeze(1)
        _, predictions = torch.max(outputs, 1)
        total += y_batch.size(0)
        correct += (predictions == y_batch).sum().item()

print('Accuracy of the network on the 5000 test diagrams: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the 5000 test diagrams: 87 %

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
model = model.cuda()
x_batch, y_batch = next(iter(dataloader))
x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
y_pred = model(x_batch)

# %%
model.requires_grad()
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-14-504627072b07> in <module>
# ----> 1 model.requires_grad()
#
# ~/conda-envs/giottodeep/lib/python3.8/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     776             if name in modules:
#     777                 return modules[name]
# --> 778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
#     779             type(self).__name__, name))
#     780
#
# ModuleAttributeError: 'SmallSetTransformer' object has no attribute 'requires_grad'

# %%
#del x_batch
#del y_batch

# %%
print('Validation accuracy of the network on the 5000 test diagrams: %2d %%' % (87.4))
