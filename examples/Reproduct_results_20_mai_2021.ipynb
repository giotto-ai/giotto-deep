# %%
# %%
from typing import List
import numpy as np  # type: ignore
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import multiprocessing
import os
from einops import rearrange  # type: ignore
from gtda.homology import WeakAlphaPersistence  # type: ignore
from gtda.plotting import plot_diagram  # type: ignore
from gdeep.topology_layers import ISAB, PMA

# %%
try:
    assert os.path.isdir('./data/ORBIT5K')
except AssertionError:
    if not os.path.isdir('./data'):
        os.mkdir('./data')
    os.mkdir('./data/ORBIT5K')

# If `use_precomputed_dgms` is `False` the ORBIT5K dataset will
# be recomputed, otherwise the ORBIT5K dataset in the folder
# `data/ORBIT5K` will be used
use_precomputed_dgms = False

dgms_filename = os.path.join('data', 'ORBIT5K',
                             'alpha_persistence_diagrams.npy')
dgms_filename_validation = os.path.join('data', 'ORBIT5K',
                                        'alpha_persistence_diagrams_' +
                                        'validation.npy')

if use_precomputed_dgms:
    try:
        assert(os.path.isfile(dgms_filename))
    except AssertionError:
        print('File data/ORBIT5K/alpha_persistence_diagrams.npy',
              ' does not exist.')
    try:
        assert(os.path.isfile(dgms_filename_validation))
    except AssertionError:
        print('File data/ORBIT5K/alpha_persistence_diagrams.npy',
              ' does not exist.')

# %%
# Create ORBIT5K dataset like in the PersLay paper
parameters = (2.5, 3.5, 4.0, 4.1, 4.3)  # different classes of orbits
homology_dimensions = (0, 1)

config = {
    'parameters': parameters,
    'num_classes': len(parameters),
    'num_orbits': 1_000,  # number of orbits per class
    'num_pts_per_orbit': 1_000,
    'homology_dimensions': homology_dimensions,
    'num_homology_dimensions': len(homology_dimensions),
    'validation_percentage': 100,  # size of validation dataset relative
    # to training
}

if not use_precomputed_dgms:
    for dataset_type in ['train', 'validation']:
        # Generate dataset consisting of 5 different orbit types with
        # 1000 sampled data points each.
        # This is the dataset ORBIT5K used in the PersLay paper
        if dataset_type == 'train':
            num_orbits = config['num_orbits']
        else:
            num_orbits = int(config['num_orbits']  # type: ignore
                             * config['validation_percentage'] / 100)
        x = np.zeros((
                        config['num_classes'],  # type: ignore
                        num_orbits,
                        config['num_pts_per_orbit'],
                        2
                    ))

        # generate dataset
        for cidx, p in enumerate(config['parameters']):  # type: ignore
            x[cidx, :, 0, :] = np.random.rand(num_orbits, 2)

            for i in range(1, config['num_pts_per_orbit']):  # type: ignore
                x_cur = x[cidx, :, i - 1, 0]
                y_cur = x[cidx, :, i - 1, 1]

                x[cidx, :, i, 0] = (x_cur + p * y_cur * (1. - y_cur)) % 1
                x_next = x[cidx, :, i, 0]
                x[cidx, :, i, 1] = (y_cur + p * x_next * (1. - x_next)) % 1

        """
        # old non-parallel version
        for cidx, p in enumerate(config['parameters']):  # type: ignore
            for i in range(config['num_orbits']):  # type: ignore
                x[cidx][i] = generate_orbit(
                    num_pts_per_orbit=config['num_pts_per_orbit'],
                    parameter=p
                    )
        """

        assert(not np.allclose(x[0, 0], x[0, 1]))

        # compute weak alpha persistence
        wap = WeakAlphaPersistence(
                            homology_dimensions=config['homology_dimensions'],
                            n_jobs=multiprocessing.cpu_count()
                            )
        # c: class, o: orbit, p: point, d: dimension
        x_stack = rearrange(x, 'c o p d -> (c o) p d')  # stack classes
        diagrams = wap.fit_transform(x_stack)
        # shape: (num_classes * n_samples, n_features, 3)

        # combine class and orbit dimensions
        diagrams = rearrange(
                                diagrams,
                                '(c o) p d -> c o p d',
                                c=config['num_classes']  # type: ignore
                            )

        # plot sample persistence diagrams for debugging
        if(False):
            plot_diagram(diagrams[1, 2])
            plot_diagram(diagrams[2, 2])

        # save dataset
        if dataset_type == 'train':
            with open(dgms_filename, 'wb') as f:
                np.save(f, diagrams)
        else:
            with open(dgms_filename_validation, 'wb') as f:
                np.save(f, diagrams)
# %%
# load dataset
for dataset_type in ['train', 'validation']:

    with open(dgms_filename, 'rb') as f:
        x = np.load(f)

    # c: class, o: orbit, p: point in persistence diagram,
    # d: coordinates + homology dimension
    x = rearrange(
                    x,
                    'c o p d -> (c o) p d',
                    c=config['num_classes']  # type: ignore
                )
    # convert homology dimension to one-hot encoding
    x = np.concatenate(
        (
            x[:, :, :2],
            (np.eye(config['num_homology_dimensions'])
             [x[:, :, -1].astype(np.int32)]),
        ),
        axis=-1)
    # convert from [orbit, sequence_length, feature] to
    # [orbit, feature, sequence_length] to fit to the
    # input_shape of `SmallSetTransformer`
    # x = rearrange(x, 'o s f -> o f s')

    # generate labels
    y_list = []
    for i in range(config['num_classes']):  # type: ignore
        y_list += [i] * config['num_orbits']  # type: ignore

    y = np.array(y_list)

    # load dataset to PyTorch dataloader

    x_tensor = torch.Tensor(x)
    y_tensor = torch.Tensor(y)

    dataset = TensorDataset(x_tensor, y_tensor)
    if dataset_type == 'train':
        dataloader = DataLoader(dataset,
                                shuffle=True,
                                batch_size=2 ** 6,
                                num_workers=6)
    else:
        dataloader_validation = DataLoader(dataset,
                                           batch_size=2 ** 6,
                                           num_workers=6)

# %%


# initialize SetTransformer model
class SetTransformer(nn.Module):
    """ Vanilla SetTransformer from
    https://github.com/juho-lee/set_transformer/blob/master/main_pointcloud.py
    """
    def __init__(
        self,
        dim_input=3,  # dimension of input data for each element in the set
        num_outputs=1,
        dim_output=40,  # number of classes
        num_inds=32,  # number of induced points, see  Set Transformer paper
        dim_hidden=128,
        num_heads=4,
        ln=False,  # use layer norm
    ):
        super(SetTransformer, self).__init__()
        self.enc = nn.Sequential(
            ISAB(dim_input, dim_hidden, num_heads, num_inds, ln=ln),
            ISAB(dim_hidden, dim_hidden, num_heads, num_inds, ln=ln),
        )
        self.dec = nn.Sequential(
            nn.Dropout(),
            PMA(dim_hidden, num_heads, num_outputs, ln=ln),
            nn.Dropout(),
            nn.Linear(dim_hidden, dim_output),
        )

    def forward(self, input):
        return self.dec(self.enc(input)).squeeze()


model = SetTransformer(dim_input=4, dim_output=5)


def num_params(model: nn.Module) -> int:
    return sum([parameter.nelement() for parameter in model.parameters()])


print('model has', num_params(model), 'trainable parameters.')  # type: ignore

# CUDA for PyTorch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")


# %%
def train(model, num_epochs: int = 10, lr: float = 1e-3,
          verbose: bool = False) -> List[float]:
    """Custom training loop for Set Transformer on the dataset ``
    Args:
        model (nn.Module): Set Transformer model to be trained
        num_epochs (int, optional): Number of training epochs. Defaults to 10.
        lr (float, optional): Learning rate for training. Defaults to 1e-3.
        verbose (bool, optional): Print training loss, training accuracy and
            validation if set to True. Defaults to False.
    Returns:
        List[float]: List of training losses
    """
    if use_cuda:
        model = nn.DataParallel(model)
        model = model.cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    losses: List[float] = []
    # training loop
    for epoch in range(num_epochs):
        model.train()
        loss_per_epoch = 0
        for x_batch, y_batch in dataloader:
            # transfer to GPU
            if use_cuda:
                x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
            loss = criterion(model(x_batch), y_batch.long())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            loss_per_epoch += loss.item()
        losses.append(loss_per_epoch)
        if verbose:
            print("epoch:", epoch, "loss:", loss_per_epoch)
            compute_accuracy(model, 'test')
            compute_accuracy(model, 'validation')
    return losses


def compute_accuracy(model, type: str = 'test') -> None:
    correct = 0
    total = 0
    if type == 'test':
        dl = dataloader
    else:
        dl = dataloader_validation

    with torch.no_grad():
        for x_batch, y_batch in dl:
            if use_cuda:
                x_batch, y_batch = x_batch.cuda(), y_batch.cuda()
            outputs = model(x_batch).squeeze(1)
            _, predictions = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predictions == y_batch).sum().item()

    print(type.capitalize(),
          'accuracy of the network on the', total,
          'diagrams: %8.2f %%' % (100 * correct / total)
          )


# %%
train(model, num_epochs=500, verbose=True)
# Out:
# model has 291589 trainable parameters.
# epoch: 0 loss: 128.43465423583984
# Test accuracy of the network on the 5000 diagrams:    19.54 %
# Validation accuracy of the network on the 5000 diagrams:    19.82 %
# epoch: 1 loss: 127.78605687618256
# Test accuracy of the network on the 5000 diagrams:    19.48 %
# Validation accuracy of the network on the 5000 diagrams:    20.54 %
# epoch: 2 loss: 127.54263913631439
# Test accuracy of the network on the 5000 diagrams:    20.34 %
# Validation accuracy of the network on the 5000 diagrams:    19.36 %
# epoch: 3 loss: 127.70188856124878
# Test accuracy of the network on the 5000 diagrams:    19.80 %
# Validation accuracy of the network on the 5000 diagrams:    18.98 %
# epoch: 4 loss: 127.40705442428589
# Test accuracy of the network on the 5000 diagrams:    19.92 %
# Validation accuracy of the network on the 5000 diagrams:    18.54 %
# epoch: 5 loss: 127.43623185157776
# Test accuracy of the network on the 5000 diagrams:    20.66 %
# Validation accuracy of the network on the 5000 diagrams:    19.46 %
# epoch: 6 loss: 127.59978806972504
# Test accuracy of the network on the 5000 diagrams:    20.10 %
# Validation accuracy of the network on the 5000 diagrams:    19.72 %
# epoch: 7 loss: 127.40756225585938
# Test accuracy of the network on the 5000 diagrams:    20.28 %
# Validation accuracy of the network on the 5000 diagrams:    19.48 %
# epoch: 8 loss: 127.34827077388763
# Test accuracy of the network on the 5000 diagrams:    19.82 %
# Validation accuracy of the network on the 5000 diagrams:    20.06 %
# epoch: 9 loss: 127.44339752197266
# Test accuracy of the network on the 5000 diagrams:    20.14 %
# Validation accuracy of the network on the 5000 diagrams:    20.66 %
# epoch: 10 loss: 127.45875382423401
# Test accuracy of the network on the 5000 diagrams:    20.66 %
# Validation accuracy of the network on the 5000 diagrams:    19.72 %
# epoch: 11 loss: 127.43387293815613
# Test accuracy of the network on the 5000 diagrams:    20.08 %
# Validation accuracy of the network on the 5000 diagrams:    20.48 %
# epoch: 12 loss: 127.29627668857574
# Test accuracy of the network on the 5000 diagrams:    20.06 %
# Validation accuracy of the network on the 5000 diagrams:    20.26 %
# epoch: 13 loss: 127.31724560260773
# Test accuracy of the network on the 5000 diagrams:    20.06 %
# Validation accuracy of the network on the 5000 diagrams:    20.48 %
# epoch: 14 loss: 127.31289553642273
# Test accuracy of the network on the 5000 diagrams:    20.32 %
# Validation accuracy of the network on the 5000 diagrams:    20.40 %
# epoch: 15 loss: 127.2538241147995
# Test accuracy of the network on the 5000 diagrams:    21.20 %
# Validation accuracy of the network on the 5000 diagrams:    20.54 %
# epoch: 16 loss: 127.20631670951843
# Test accuracy of the network on the 5000 diagrams:    19.90 %
# Validation accuracy of the network on the 5000 diagrams:    19.82 %
# epoch: 17 loss: 127.32400703430176
# Test accuracy of the network on the 5000 diagrams:    19.88 %
# Validation accuracy of the network on the 5000 diagrams:    19.96 %
# epoch: 18 loss: 127.3118587732315
# Test accuracy of the network on the 5000 diagrams:    20.46 %
# Validation accuracy of the network on the 5000 diagrams:    20.26 %
# epoch: 19 loss: 127.35974156856537
# Test accuracy of the network on the 5000 diagrams:    20.82 %
# Validation accuracy of the network on the 5000 diagrams:    20.52 %
# epoch: 20 loss: 127.26410210132599
# Test accuracy of the network on the 5000 diagrams:    20.82 %
# Validation accuracy of the network on the 5000 diagrams:    21.12 %
# epoch: 21 loss: 127.2933304309845
# Test accuracy of the network on the 5000 diagrams:    20.16 %
# Validation accuracy of the network on the 5000 diagrams:    20.08 %
# epoch: 22 loss: 127.24492263793945
# Test accuracy of the network on the 5000 diagrams:    20.14 %
# Validation accuracy of the network on the 5000 diagrams:    19.92 %
# epoch: 23 loss: 127.19129824638367
# Test accuracy of the network on the 5000 diagrams:    20.94 %
# Validation accuracy of the network on the 5000 diagrams:    20.22 %
# epoch: 24 loss: 127.23867499828339
# Test accuracy of the network on the 5000 diagrams:    20.08 %
# Validation accuracy of the network on the 5000 diagrams:    20.00 %
# epoch: 25 loss: 127.18598818778992
# Test accuracy of the network on the 5000 diagrams:    21.52 %
# Validation accuracy of the network on the 5000 diagrams:    22.00 %
# epoch: 26 loss: 127.14183461666107
# Test accuracy of the network on the 5000 diagrams:    21.30 %
# Validation accuracy of the network on the 5000 diagrams:    21.12 %
# epoch: 27 loss: 127.16810071468353
# Test accuracy of the network on the 5000 diagrams:    21.00 %
# Validation accuracy of the network on the 5000 diagrams:    22.18 %
# epoch: 28 loss: 127.19790613651276
# Test accuracy of the network on the 5000 diagrams:    22.36 %
# Validation accuracy of the network on the 5000 diagrams:    21.78 %
# epoch: 29 loss: 126.83528518676758
# Test accuracy of the network on the 5000 diagrams:    21.82 %
# Validation accuracy of the network on the 5000 diagrams:    21.42 %
# epoch: 30 loss: 126.64188396930695
# Test accuracy of the network on the 5000 diagrams:    20.76 %
# Validation accuracy of the network on the 5000 diagrams:    21.60 %
# epoch: 31 loss: 127.37898421287537
# Test accuracy of the network on the 5000 diagrams:    21.40 %
# Validation accuracy of the network on the 5000 diagrams:    20.78 %
# epoch: 32 loss: 126.6927570104599
# Test accuracy of the network on the 5000 diagrams:    19.76 %
# Validation accuracy of the network on the 5000 diagrams:    19.88 %
# epoch: 33 loss: 127.03667950630188
# Test accuracy of the network on the 5000 diagrams:    21.96 %
# Validation accuracy of the network on the 5000 diagrams:    20.68 %
# epoch: 34 loss: 127.1336499452591
# Test accuracy of the network on the 5000 diagrams:    21.00 %
# Validation accuracy of the network on the 5000 diagrams:    20.26 %
# epoch: 35 loss: 127.02402079105377
# Test accuracy of the network on the 5000 diagrams:    21.52 %
# Validation accuracy of the network on the 5000 diagrams:    21.68 %
# epoch: 36 loss: 126.46275770664215
# Test accuracy of the network on the 5000 diagrams:    31.46 %
# Validation accuracy of the network on the 5000 diagrams:    31.60 %
# epoch: 37 loss: 124.64741706848145
# Test accuracy of the network on the 5000 diagrams:    28.12 %
# Validation accuracy of the network on the 5000 diagrams:    28.34 %
# epoch: 38 loss: 122.9453774690628
# Test accuracy of the network on the 5000 diagrams:    21.08 %
# Validation accuracy of the network on the 5000 diagrams:    21.14 %
# epoch: 39 loss: 125.90857565402985
# Test accuracy of the network on the 5000 diagrams:    20.68 %
# Validation accuracy of the network on the 5000 diagrams:    20.96 %
# epoch: 40 loss: 124.28945708274841
# Test accuracy of the network on the 5000 diagrams:    30.70 %
# Validation accuracy of the network on the 5000 diagrams:    31.40 %
# epoch: 41 loss: 121.88105547428131
# Test accuracy of the network on the 5000 diagrams:    27.56 %
# Validation accuracy of the network on the 5000 diagrams:    27.08 %
# epoch: 42 loss: 125.07325732707977
# Test accuracy of the network on the 5000 diagrams:    27.16 %
# Validation accuracy of the network on the 5000 diagrams:    28.16 %
# epoch: 43 loss: 123.54615831375122
# Test accuracy of the network on the 5000 diagrams:    20.40 %
# Validation accuracy of the network on the 5000 diagrams:    22.32 %
# epoch: 44 loss: 121.55071663856506
# Test accuracy of the network on the 5000 diagrams:    31.34 %
# Validation accuracy of the network on the 5000 diagrams:    31.88 %
# epoch: 45 loss: 117.56634104251862
# Test accuracy of the network on the 5000 diagrams:    27.84 %
# Validation accuracy of the network on the 5000 diagrams:    28.54 %
# epoch: 46 loss: 116.44311809539795
# Test accuracy of the network on the 5000 diagrams:    20.84 %
# Validation accuracy of the network on the 5000 diagrams:    20.98 %
# epoch: 47 loss: 117.97319543361664
# Test accuracy of the network on the 5000 diagrams:    21.54 %
# Validation accuracy of the network on the 5000 diagrams:    21.60 %
# epoch: 48 loss: 120.7357360124588
# Test accuracy of the network on the 5000 diagrams:    26.16 %
# Validation accuracy of the network on the 5000 diagrams:    26.04 %
# epoch: 49 loss: 114.51802945137024
# Test accuracy of the network on the 5000 diagrams:    31.20 %
# Validation accuracy of the network on the 5000 diagrams:    31.18 %
# epoch: 50 loss: 112.37828552722931
# Test accuracy of the network on the 5000 diagrams:    33.20 %
# Test accuracy of the network on the 5000 diagrams:    89.34 %
# Validation accuracy of the network on the 5000 diagrams:    89.20 %
# epoch: 275 loss: 20.374355405569077
# Test accuracy of the network on the 5000 diagrams:    89.86 %
# Validation accuracy of the network on the 5000 diagrams:    89.86 %
# epoch: 276 loss: 20.57640241086483
# Test accuracy of the network on the 5000 diagrams:    88.50 %
# Validation accuracy of the network on the 5000 diagrams:    88.92 %
# epoch: 277 loss: 19.934649616479874
# Test accuracy of the network on the 5000 diagrams:    89.76 %
# Validation accuracy of the network on the 5000 diagrams:    89.84 %
# epoch: 278 loss: 19.656020000576973
# Test accuracy of the network on the 5000 diagrams:    90.30 %
# Validation accuracy of the network on the 5000 diagrams:    90.36 %
# epoch: 279 loss: 20.133831724524498
# Test accuracy of the network on the 5000 diagrams:    87.92 %
# Validation accuracy of the network on the 5000 diagrams:    87.56 %
# epoch: 280 loss: 20.37047601491213
# Test accuracy of the network on the 5000 diagrams:    89.74 %
# Validation accuracy of the network on the 5000 diagrams:    90.18 %
# epoch: 281 loss: 19.925693966448307
# Test accuracy of the network on the 5000 diagrams:    90.62 %
# Validation accuracy of the network on the 5000 diagrams:    90.44 %
# epoch: 282 loss: 20.0113787651062
# Test accuracy of the network on the 5000 diagrams:    88.96 %
# Validation accuracy of the network on the 5000 diagrams:    88.40 %
# epoch: 283 loss: 20.26339603587985
# Test accuracy of the network on the 5000 diagrams:    87.02 %
# Validation accuracy of the network on the 5000 diagrams:    86.50 %
# epoch: 284 loss: 24.398495979607105
# Test accuracy of the network on the 5000 diagrams:    88.92 %
# Validation accuracy of the network on the 5000 diagrams:    88.98 %
# epoch: 285 loss: 21.37552110105753
# Test accuracy of the network on the 5000 diagrams:    89.56 %
# Validation accuracy of the network on the 5000 diagrams:    89.36 %
# epoch: 286 loss: 20.451714247465134
# Test accuracy of the network on the 5000 diagrams:    87.08 %
# Validation accuracy of the network on the 5000 diagrams:    87.46 %
# epoch: 287 loss: 21.23692612722516
# Test accuracy of the network on the 5000 diagrams:    89.70 %
# Validation accuracy of the network on the 5000 diagrams:    90.18 %
# epoch: 288 loss: 22.209839522838593
# Test accuracy of the network on the 5000 diagrams:    89.62 %
# Validation accuracy of the network on the 5000 diagrams:    89.82 %
# epoch: 289 loss: 21.422928161919117
# Test accuracy of the network on the 5000 diagrams:    90.58 %
# Validation accuracy of the network on the 5000 diagrams:    90.18 %
# epoch: 290 loss: 21.955970712006092
# ...
# Validation accuracy of the network on the 5000 diagrams:    88.54 %
# epoch: 466 loss: 19.000022634863853
# Test accuracy of the network on the 5000 diagrams:    90.40 %
# Validation accuracy of the network on the 5000 diagrams:    90.26 %
# epoch: 467 loss: 18.762095723301172
# Test accuracy of the network on the 5000 diagrams:    89.46 %
# Validation accuracy of the network on the 5000 diagrams:    89.78 %
# epoch: 468 loss: 19.74691019207239
# Test accuracy of the network on the 5000 diagrams:    90.66 %
# Validation accuracy of the network on the 5000 diagrams:    90.56 %
# epoch: 469 loss: 18.72719694674015
# Test accuracy of the network on the 5000 diagrams:    90.78 %
# Validation accuracy of the network on the 5000 diagrams:    90.62 %
# Test accuracy of the network on the 5000 diagrams:    89.06 %
# Validation accuracy of the network on the 5000 diagrams:    88.76 %
# epoch: 491 loss: 18.843115285038948
# Test accuracy of the network on the 5000 diagrams:    90.94 %
# Validation accuracy of the network on the 5000 diagrams:    90.78 %
# epoch: 492 loss: 18.52514056954533
# Test accuracy of the network on the 5000 diagrams:    90.38 %
# Validation accuracy of the network on the 5000 diagrams:    91.08 %
# epoch: 493 loss: 19.141666904091835
# Test accuracy of the network on the 5000 diagrams:    90.62 %
# Validation accuracy of the network on the 5000 diagrams:    90.36 %
# epoch: 494 loss: 20.18588227778673
# Test accuracy of the network on the 5000 diagrams:    90.80 %
# Validation accuracy of the network on the 5000 diagrams:    90.32 %
# epoch: 495 loss: 20.90593881905079
# Test accuracy of the network on the 5000 diagrams:    88.80 %
# Validation accuracy of the network on the 5000 diagrams:    89.44 %
# epoch: 496 loss: 20.551700353622437
# Test accuracy of the network on the 5000 diagrams:    88.10 %
# Validation accuracy of the network on the 5000 diagrams:    88.22 %
# epoch: 497 loss: 19.485870704054832
# Test accuracy of the network on the 5000 diagrams:    90.50 %
# Validation accuracy of the network on the 5000 diagrams:    90.78 %
# epoch: 498 loss: 19.158110089600086
# Test accuracy of the network on the 5000 diagrams:    90.54 %
# Validation accuracy of the network on the 5000 diagrams:    90.14 %
# epoch: 499 loss: 19.535780772566795
# Test accuracy of the network on the 5000 diagrams:    90.74 %
# Validation accuracy of the network on the 5000 diagrams:    90.38 %
# [128.43465423583984,
#  127.78605687618256,
#  127.54263913631439,
#  127.70188856124878,
#  127.40705442428589,
#  127.43623185157776,
#  127.59978806972504,
#  127.40756225585938,
#  127.34827077388763,
#  127.44339752197266,
#  127.45875382423401,
#  127.43387293815613,
#  127.29627668857574,
#  127.31724560260773,
#  127.31289553642273,
#  127.2538241147995,
#  127.20631670951843,
#  127.32400703430176,
#  127.3118587732315,
#  127.35974156856537,
#  127.26410210132599,
#  127.2933304309845,
#  127.24492263793945,
#  127.19129824638367,
#  127.23867499828339,
#  127.18598818778992,
#  127.14183461666107,
#  127.16810071468353,
#  127.19790613651276,
#  126.83528518676758,
#  126.64188396930695,
#  127.37898421287537,
#  126.6927570104599,
#  127.03667950630188,
#  127.1336499452591,
#  127.02402079105377,
#  126.46275770664215,
#  124.64741706848145,
#  122.9453774690628,
#  125.90857565402985,
#  124.28945708274841,
#  121.88105547428131,
#  125.07325732707977,
#  123.54615831375122,
#  121.55071663856506,
#  117.56634104251862,
#  116.44311809539795,
#  117.97319543361664,
#  120.7357360124588,
#  114.51802945137024,
#  112.37828552722931,
#  111.09530258178711,
#  100.15738624334335,
#  93.2746929526329,
#  83.0915042757988,
#  73.79250580072403,
#  69.54709005355835,
#  67.93837451934814,
#  57.10577988624573,
#  57.33775232732296,
#  49.2125209569931,
#  46.96481356024742,
#  41.86695356667042,
#  39.737012058496475,
#  38.3132549226284,
#  33.2489247918129,
#  31.943409636616707,
#  33.57487401366234,
#  31.926798924803734,
#  30.242985174059868,
#  30.65760238468647,
#  29.409178510308266,
#  31.292895145714283,
#  26.725014954805374,
#  26.729787155985832,
